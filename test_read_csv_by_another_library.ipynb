# %%
import pandas
import numpy as np
result = pandas.read_csv('drive/My Drive/korat_sauce/img_hog_li.csv')
print(result)
# Out:
#       2  0.19745912472591767  ...  0.25005248667943447.8  0.12841238369527969
# 0     4             0.056315  ...               0.047412             0.256372
# 1     3             0.244832  ...               0.004122             0.030428
# 2     4             0.265379  ...               0.039980             0.123368
# 3     2             0.250287  ...               0.113441             0.273610
# 4     1             0.230354  ...               0.109837             0.032242
# ...  ..                  ...  ...                    ...                  ...
# 2712  1             0.272490  ...               0.048471             0.220205
# 2713  3             0.242615  ...               0.114742             0.218949
# 2714  1             0.268877  ...               0.109261             0.180742
# 2715  1             0.316511  ...               0.229208             0.239578
# 2716  2             0.309620  ...               0.129009             0.127026
#
# [2717 rows x 3781 columns]

# %%
result['1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-bca1cc219dfa> in <module>()
# ----> 1 result['1']
#
# ...

# %%
my_all_data = pandas.read_csv('drive/My Drive/korat_sauce/img_hog_li.csv', header = None,na_values=0)
my_all_data
# Out:
#       0         1         2     ...      3778      3779      3780
# 0        2  0.197459  0.053941  ...  0.185742  0.250052  0.128412
# 1        4  0.056315  0.014199  ...  0.256372  0.047412  0.256372
# 2        3  0.244832  0.135188  ...  0.019965  0.004122  0.030428
# 3        4  0.265379  0.202856  ...  0.099510  0.039980  0.123368
# 4        2  0.250287  0.250287  ...  0.040760  0.113441  0.273610
# ...    ...       ...       ...  ...       ...       ...       ...
# 2713     1  0.272490  0.115334  ...  0.029890  0.048471  0.220205
# 2714     3  0.242615  0.081651  ...  0.066933  0.114742  0.218949
# 2715     1  0.268877  0.101634  ...  0.132138  0.109261  0.180742
# 2716     1  0.316511  0.053017  ...  0.046161  0.229208  0.239578
# 2717     2  0.309620  0.156711  ...  0.125595  0.129009  0.127026
#
# [2718 rows x 3781 columns]

# %%
mydata0 = pandas.read_csv('drive/My Drive/korat_sauce/img_hog_li.csv', header = None,na_values=0,skiprows = 2, nrows=2)
mydata0
# Out:
#    0         1         2         3     ...      3777      3778      3779      3780
# 0     3  0.244832  0.135188  0.204078  ...  0.105379  0.019965  0.004122  0.030428
# 1     4  0.265379  0.202856  0.055717  ...  0.142370  0.099510  0.039980  0.123368
#
# [2 rows x 3781 columns]

# %%
my_data =  np.array(mydata0)
type(np.array(mydata0))
# Out:
# numpy.ndarray

# %%
my_data[0][0]
# Out:
# 3.0

# %%
my_data_for_use = np.array(my_all_data)
my_data_for_use
# Out:
# array([[2.        , 0.19745912, 0.05394141, ..., 0.18574194, 0.25005249,
#         0.12841238],
#        [4.        , 0.056315  , 0.01419856, ..., 0.25637245, 0.04741205,
#         0.25637245],
#        [3.        , 0.24483227, 0.13518799, ..., 0.01996475, 0.00412176,
#         0.03042838],
#        ...,
#        [1.        , 0.26887748, 0.10163358, ..., 0.13213796, 0.10926053,
#         0.18074177],
#        [1.        , 0.31651051, 0.05301685, ..., 0.04616125, 0.22920833,
#         0.23957834],
#        [2.        , 0.30961964, 0.15671149, ..., 0.12559484, 0.12900911,
#         0.12702554]])

# %%
my_data_for_use[0][1]
# Out:
# 0.19745912472591767

# %%
my_all_data2 = pandas.read_csv('drive/My Drive/korat_sauce/img_hog_li.csv', header = None,na_values=0)
my_all_data2.loc[:, my_all_data2.columns != 0]
# Out:
#           1         2         3     ...      3778      3779      3780
# 0     0.197459  0.053941  0.027235  ...  0.185742  0.250052  0.128412
# 1     0.056315  0.014199  0.032202  ...  0.256372  0.047412  0.256372
# 2     0.244832  0.135188  0.204078  ...  0.019965  0.004122  0.030428
# 3     0.265379  0.202856  0.055717  ...  0.099510  0.039980  0.123368
# 4     0.250287  0.250287  0.177428  ...  0.040760  0.113441  0.273610
# ...        ...       ...       ...  ...       ...       ...       ...
# 2713  0.272490  0.115334  0.074488  ...  0.029890  0.048471  0.220205
# 2714  0.242615  0.081651  0.014636  ...  0.066933  0.114742  0.218949
# 2715  0.268877  0.101634  0.056684  ...  0.132138  0.109261  0.180742
# 2716  0.316511  0.053017  0.043821  ...  0.046161  0.229208  0.239578
# 2717  0.309620  0.156711  0.051739  ...  0.125595  0.129009  0.127026
#
# [2718 rows x 3780 columns]

# %%
my_all_data2[0]
# Out:
# 0       2
# 1       4
# 2       3
# 3       4
# 4       2
#        ..
# 2713    1
# 2714    3
# 2715    1
# 2716    1
# 2717    2
# Name: 0, Length: 2718, dtype: int64

# %%
num_prodct = np.array(my_all_data2[0])
num_prodct = np.transpose(num_prodct)
# Out:
# (2718,)

# %%
test_int = np.array([0,1,2,3])
test_int.shape
# Out:
# (4,)

# %%
my_all_data2_form_my_data= pandas.read_csv('drive/My Drive/korat_sauce/img_hog.csv', header = None,na_values=0)
my_all_data2_form_my_data.loc[:, my_all_data2_form_my_data.columns != 0]
# Out:
#           1         2         3     ...      3778      3779      3780
# 0     0.272372  0.247184  0.361081  ...  0.093656  0.028308  0.077341
# 1     0.022358  0.114254  0.033844  ...  0.036977  0.190345  0.249683
# 2     0.151328  0.281404  0.163745  ...  0.110842  0.085444  0.199249
# 3     0.228140  0.198487  0.035437  ...  0.221546  0.093726  0.217581
# 4     0.335879  0.150910  0.017654  ...  0.122287  0.094382  0.310952
# ...        ...       ...       ...  ...       ...       ...       ...
# 2713  0.138293  0.313715  0.045381  ...  0.136884  0.098900  0.185439
# 2714  0.208820  0.176984  0.112904  ...  0.119135  0.125568  0.248611
# 2715  0.115081  0.142604  0.028818  ...  0.095795  0.170725  0.372749
# 2716  0.421492  0.369990  0.152492  ...  0.111502  0.043295  0.171459
# 2717  0.301571  0.076688  0.127177  ...  0.329461  0.338360  0.197025
#
# [2718 rows x 3780 columns]
