# %%
import time
import numpy as np
import cv2
import scipy.special
import matplotlib.pyplot as plt
import os
import csv

from os import listdir
from os.path import isfile, join
import pandas
from scipy import ndimage
import random

# %%
def to_crop_img(image):
  #image = cv2.imread(img_name)


  img = image.copy()
  image = cv2.resize(img,(len(img[0])//5,len(img)//5))

  img = cv2.blur(img,(15,15))

  img = cv2.resize(img,(len(img[0])//5,len(img)//5))

  img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

  # Find Canny edges
  #edged = cv2.Canny(img, 25, 250)
  edged = cv2.threshold(img, 125, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]


  contours, hierarchy = cv2.findContours(edged, 
      cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

  max_position = 0
  max_value = 0
  for i in range(len(contours)):
      #print(contours[i].shape)
      if(contours[i].shape[0]>max_value):
          max_value = contours[i].shape[0]
          max_position = i
          

  x,y,w,h = cv2.boundingRect(contours[max_position])
  #print(w,' ',h,' ',w/h)
  crop_img = image[y:y+h, x:x+w]

  if(w/h > 0.59):
      rotate = ndimage.rotate(crop_img, 0-((w/h-0.54)*100),cval=205.0)
      img_rotate = cv2.blur(rotate,(1,1))
      img_rotate = cv2.cvtColor(img_rotate, cv2.COLOR_BGR2GRAY)
      rotate_edged = cv2.threshold(img_rotate, 125, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
      #cv2.imshow('img_rotate',rotate_edged)
      contours_rotate, hierarchy_rotate = cv2.findContours(rotate_edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
      max_position_rotate = 0
      max_value_rotate = 0
      for i in range(len(contours_rotate)):
          #print(contours[i].shape)
          if(contours_rotate[i].shape[0]>max_value_rotate):
              max_value_rotate = contours_rotate[i].shape[0]
              max_position_rotate = i
      x_rotate,y_rotate,w_rotate,h_rotate = cv2.boundingRect(contours_rotate[max_position_rotate])
      crop_img_rotate = rotate[y_rotate:y_rotate+h_rotate, x_rotate:x_rotate+w_rotate]
      #print(w_rotate/h_rotate)
      ratio_unclockwise = w_rotate/h_rotate
      if(w_rotate/h_rotate >0.59):
          rotate = ndimage.rotate(crop_img, ((w/h-0.57)*100),cval=205.0)
          img_rotate = cv2.blur(rotate,(1,1))
          img_rotate = cv2.cvtColor(img_rotate, cv2.COLOR_BGR2GRAY)
          rotate_edged = cv2.threshold(img_rotate, 125, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
          #cv2.imshow('img_rotate',rotate_edged)
          contours_rotate, hierarchy_rotate = cv2.findContours(rotate_edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
          max_position_rotate = 0
          max_value_rotate = 0
          for i in range(len(contours_rotate)):
              #print(contours[i].shape)
              if(contours_rotate[i].shape[0]>max_value_rotate):
                  max_value_rotate = contours_rotate[i].shape[0]
                  max_position_rotate = i
          x_rotate,y_rotate,w_rotate,h_rotate = cv2.boundingRect(contours_rotate[max_position_rotate])
          crop_img_rotate = rotate[y_rotate:y_rotate+h_rotate, x_rotate:x_rotate+w_rotate]
          #print(w_rotate/h_rotate)
          ratio_clockwise = w_rotate/h_rotate
          if (ratio_clockwise>ratio_unclockwise):
            rotate = ndimage.rotate(crop_img, 0-((w/h-0.54)*100),cval=205.0)
            img_rotate = cv2.blur(rotate,(1,1))
            img_rotate = cv2.cvtColor(img_rotate, cv2.COLOR_BGR2GRAY)
            rotate_edged = cv2.threshold(img_rotate, 125, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
            #cv2.imshow('img_rotate',rotate_edged)
            contours_rotate, hierarchy_rotate = cv2.findContours(rotate_edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
            max_position_rotate = 0
            max_value_rotate = 0
            for i in range(len(contours_rotate)):
                #print(contours[i].shape)
                if(contours_rotate[i].shape[0]>max_value_rotate):
                    max_value_rotate = contours_rotate[i].shape[0]
                    max_position_rotate = i
            x_rotate,y_rotate,w_rotate,h_rotate = cv2.boundingRect(contours_rotate[max_position_rotate])
            crop_img_rotate = rotate[y_rotate:y_rotate+h_rotate, x_rotate:x_rotate+w_rotate]
            #print(w_rotate/h_rotate)
      #cv2.imshow('rotate',crop_img_rotate)
      crop_img = crop_img_rotate #
  return crop_img

# %%
def avg_in_scale(crop_img):
  crop_img = img = cv2.resize(crop_img,(275,512))
  avg_scale_from_crop = []
  count = 0
  for row_line in range(len(crop_img)//30-2):
    for col_line in range(len(crop_img[0])//30-2):
      img_scale = crop_img[(row_line+1)*30:(row_line+1)*30+30, (col_line+1)*30:(col_line+1)*30+30]
      avg_pix = 0
      for row in range(len(img_scale)):
        for col in range(len(img_scale[0])):
          avg_pix += sum(img_scale[row][col])/3
      avg_scale_from_crop.append(avg_pix)
      count+=1


  return np.array(avg_scale_from_crop)

# %%
def detect_orange(img):
  img = cv2.resize(img,(184,409))

  hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
  hsv = cv2.blur(cv2.cvtColor(img,cv2.COLOR_BGR2HSV),(10,10))

  lower_orange = np.array([10,120,120])
  upper_orange = np.array([20,255,255])
  mask1 = cv2.inRange(hsv, lower_orange, upper_orange)
  #cv2.imshow('mask1',mask1)
  white_val = 0
  for row in range(len(mask1)):
      white_val += sum(mask1[row])/255
  return white_val

def detect_yellow(img):
  img = cv2.resize(img,(184,409))

  hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
  hsv = cv2.blur(cv2.cvtColor(img,cv2.COLOR_BGR2HSV),(10,10))

  lower_yellow = np.array([18,120,120])
  upper_yellow = np.array([25,255,255])
  mask1 = cv2.inRange(hsv, lower_yellow, upper_yellow)
  #cv2.imshow('mask1',mask1)
  white_val = 0
  for row in range(len(mask1)):
      white_val += sum(mask1[row])/255
  return white_val

def detect_green(img):
  img = cv2.resize(img,(184,409))

  hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
  hsv = cv2.blur(cv2.cvtColor(img,cv2.COLOR_BGR2HSV),(10,10))

  lower_green = np.array([35,50,120])
  upper_green = np.array([80,255,255])
  mask1 = cv2.inRange(hsv, lower_green, upper_green)
  #cv2.imshow('mask1',mask1)
  white_val = 0
  for row in range(len(mask1)):
      white_val += sum(mask1[row])/255
  return white_val

# %%
def color_in_scale(crop_img):
  crop_img = img = cv2.resize(crop_img,(275,512))
  color_scale_from_crop = []
  count = 0
  for row_line in range(len(crop_img)//30-2):
    for col_line in range(len(crop_img[0])//30-2):
      img_scale = crop_img[(row_line+1)*30:(row_line+1)*30+30, (col_line+1)*30:(col_line+1)*30+30]
      num_white = 0
      if (row_line == 2 ):
          num_white   = detect_green(img_scale)
          pass
      elif (row_line == 3):
          if (col_line < 2 or col_line >5):
              num_white   = detect_green(img_scale)
          else:
              num_white   = detect_orange(img_scale)        
          pass
      elif (row_line == 4):
          if (col_line < 2 or col_line == 6 ):
              num_white   = detect_green(img_scale)
          else:
              num_white   = detect_orange(img_scale)        
          pass
      elif (row_line == 11):
          num_white   = detect_yellow(img_scale)  
          pass
      elif (row_line == 12):
          num_white   = detect_yellow(img_scale)  
          pass
      else:
          num_white   = detect_orange(img_scale)  
      color_scale_from_crop.append(num_white)
      count+=1

  return np.array(color_scale_from_crop)

# %%
# neural network class definition
class neuralNetwork :

    # initialise the neural network
    def __init__(self, inputnodes, hiddennodes, outputnodes,learningrate,send_weight_state = False,weight = 0,send_bias_state = False,bias_set = 0) :


        # set number of nodes in each input, hidden, output layer
        self.inodes = inputnodes
        self.hnodes = hiddennodes
        self.onodes = outputnodes
        self.weight_each_epochs = []
        self.bias_each_epochs = []

        self.set_w  = []
        if (send_weight_state):
            self.set_w = weight
        #set weight
        else:
            #self.w = np.random.normal(0.0, pow(self.onodes, -0.5),(self.onodes, self.inodes))
            self.set_w.append(np.random.normal(0.0, pow(self.inodes, -0.5),(self.hnodes[0], self.inodes)))
            for i in range(1,len(self.hnodes)):
                self.set_w.append(np.random.normal(0.0, pow(self.hnodes[i-1], -0.5),(self.hnodes[i], self.hnodes[i-1])))
            self.set_w.append(np.random.normal(0.0, pow(self.hnodes[-1], -0.5),(self.onodes, self.hnodes[-1])))
        self.set_w = np.array(self.set_w)

        
        # learning rate
        self.lr = learningrate
        self.bias = []
        if (send_bias_state):
            self.bias = bias_set
        else:
            for i in range(len(self.hnodes)+1):
                self.bias.append(1)
        self.bias = np.array(self.bias)
        

        # activation function is the sigmoid function
        self.activation_function = lambda x: scipy.special.expit(x)
        #self.derivative_function = lambda x: 1 if x>0 else 0 if x==0 else -1

        pass
   
    

    # train the neural network
    def train(self, inputs_list, targets_list) :
        # convert inputs list to 2d array
        inputs = np.array(inputs_list, ndmin=2).T
        targets = np.array(targets_list, ndmin=2).T
        # print('targets = ', targets)

        result_each_layer_set = []
        # w_dot_input = np.dot(self.w, inputs)
        # outputs = self.activation_function(w_dot_input+1)
        result_each_layer_set.append(self.activation_function(np.dot(self.set_w[0], inputs)+self.bias[0]))
        for i in range(len(self.hnodes)):
            result_each_layer_set.append(self.activation_function(np.dot(self.set_w[i+1], result_each_layer_set[i])+self.bias[i+1]))
        

        # output layer error is the (target actual)
        #output_errors = targets-outputs
        error_set = []
        output_errors = targets-result_each_layer_set[-1]
        
        error_set.append(output_errors)
        for i in range(len(self.hnodes)):
            error_set.append(np.dot(self.set_w[0-(i+1)].T,error_set[i]))
        
        # print(error_set)
        # print(self.set_w)



        
        
        # update the weights 
       
        # self.w += self.lr * np.dot((output_errors*outputs * (1.0-outputs)),np.transpose(inputs)) 
        for i in range(len(error_set)-1):
            self.set_w[0-(i+1)] += self.lr * np.dot((error_set[i] * result_each_layer_set[0-(i+1)] * (1.0 - result_each_layer_set[0-(i+1)])), np.transpose(result_each_layer_set[0-(i+2)]))
            self.bias[0-(i+1)] +=  self.lr*self.bias[0-(i+1)] *sum(error_set[i] * result_each_layer_set[0-(i+1)] * (1.0 - result_each_layer_set[0-(i+1)]))
        self.set_w[0] += self.lr * np.dot((error_set[-1] * result_each_layer_set[0] * (1.0 - result_each_layer_set[0])), np.transpose(inputs))
        self.bias[0] +=  self.lr *self.bias[0] *sum(error_set[-1] * result_each_layer_set[0] * (1.0 - result_each_layer_set[0]))
        self.weight_each_epochs.append(self.set_w.copy())
        self.bias_each_epochs.append(self.bias.copy())



        # print("*********")
        pass

    # query the neural network
    def query(self, inputs_list) :

        # convert inputs list to 2d array
        inputs = np.array(inputs_list, ndmin=2).T


        # output = np.dot(self.w, inputs)

        # # calculate the signals emerging 
        # final_outputs = self.activation_function(output)

        result_each_layer_set = []
        result_each_layer_set.append(self.activation_function(np.dot(self.set_w[0], inputs)+self.bias[0]))
        for i in range(len(self.hnodes)):
            result_each_layer_set.append(self.activation_function(np.dot(self.set_w[i+1], result_each_layer_set[i])+self.bias[i+1]))
        
        final_outputs = result_each_layer_set[-1]

        return final_outputs
    
   
    # def write_weight(self) :
    #     f = open('weight.txt','w',encoding='utf-8')
    #     # f.write(str(self.set_w))
    #     for i in self.set_w:
    #         f.write(str(i))
    #         f.write('/')
    #     f.close()
    #     print('already write!! ')

# %%
from google.colab import drive
drive.mount('/content/drive')

# !unzip drive/"My Drive"/korat_sauce/train_data_use_color2.zip
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archive:  drive/My Drive/korat_sauce/train_data_use_color2.zip
#    creating: train_data/
#   inflating: train_data/maeyupa.0.jpg
#   inflating: train_data/maeyupa.1.jpg
#   inflating: train_data/maeyupa.100.jpg
#   inflating: train_data/maeyupa.101.jpg
#   inflating: train_data/maeyupa.108.jpg
#   inflating: train_data/maeyupa.109.jpg
#   inflating: train_data/maeyupa.110.jpg
#   inflating: train_data/maeyupa.111.jpg
#   inflating: train_data/maeyupa.112.jpg
#   inflating: train_data/maeyupa.113.jpg
#   inflating: train_data/maeyupa.12.jpg
#   inflating: train_data/maeyupa.120.jpg
#   inflating: train_data/maeyupa.121.jpg
#   inflating: train_data/maeyupa.122.jpg
#   inflating: train_data/maeyupa.123.jpg
#   inflating: train_data/maeyupa.124.jpg
#   inflating: train_data/maeyupa.125.jpg
#   inflating: train_data/maeyupa.13.jpg
#   inflating: train_data/maeyupa.132.jpg
#   inflating: train_data/maeyupa.133.jpg
#   inflating: train_data/maeyupa.134.jpg
#   inflating: train_data/maeyupa.135.jpg
#   inflating: train_data/maeyupa.136.jpg
#   inflating: train_data/maeyupa.137.jpg
#   inflating: train_data/maeyupa.14.jpg
#   inflating: train_data/zapnuerchick.40.jpg
#   inflating: train_data/zapnuerchick.41.jpg
#   inflating: train_data/zapnuerchick.42.jpg
#   inflating: train_data/zapnuerchick.43.jpg
#   inflating: train_data/zapnuerchick.44.jpg
#   inflating: train_data/zapnuerchick.5.jpg
#   inflating: train_data/zapnuerchick.51.jpg
#   inflating: train_data/zapnuerchick.52.jpg
#   inflating: train_data/zapnuerchick.53.jpg
#   inflating: train_data/zapnuerchick.54.jpg
#   inflating: train_data/zapnuerchick.55.jpg
#   inflating: train_data/zapnuerchick.56.jpg
#   inflating: train_data/zapnuerchick.6.jpg
#   inflating: train_data/zapnuerchick.63.jpg
#   inflating: train_data/zapnuerchick.64.jpg
#   inflating: train_data/zapnuerchick.65.jpg
#   inflating: train_data/zapnuerchick.66.jpg
#   inflating: train_data/zapnuerchick.67.jpg
#   inflating: train_data/zapnuerchick.68.jpg
#   inflating: train_data/zapnuerchick.7.jpg
#   inflating: train_data/zapnuerchick.75.jpg
#   inflating: train_data/zapnuerchick.76.jpg
#   inflating: train_data/zapnuerchick.77.jpg
#   inflating: train_data/zapnuerchick.78.jpg
#   inflating: train_data/zapnuerchick.79.jpg
#   inflating: train_data/zapnuerchick.8.jpg
#   inflating: train_data/zapnuerchick.80.jpg
#   inflating: train_data/zapnuerchick.87.jpg
#   inflating: train_data/zapnuerchick.88.jpg
#   inflating: train_data/zapnuerchick.89.jpg
#   inflating: train_data/zapnuerchick.90.jpg
#   inflating: train_data/zapnuerchick.91.jpg
#   inflating: train_data/zapnuerchick.92.jpg
#   inflating: train_data/zapnuerchick.99.jpg

# %%
mypath = 'train_data/'
imagePaths = [mypath+f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
train_list = []
train_list_ans = []

for (i, img_path) in enumerate(imagePaths):
      img = cv2.imread(img_path)
      crop_img = to_crop_img(img) 
      # orange_val = detect_orange(img)
      # yellow_val = detect_yellow(img)
      # green_val = detect_green(img)
      # color_list = np.array([orange_val,yellow_val,green_val])
      #train_list.append(np.array([(x-min(color_list))/(max(color_list)-min(color_list))  for x in color_list])+0.01)
      avg_img = color_in_scale(crop_img)
      min_avg = min(avg_img)
      max_avg = max(avg_img)
      for i in range(len(avg_img)):
          avg_img[i] = (avg_img[i]-min_avg)/(max_avg-min_avg)
      train_list.append(avg_img)
      product_name = img_path.split(".")[0].split("/")[1]
      product_class = 0
      if (product_name == "maeyupa"):
          product_class = 1
      elif (product_name == "ocean"):
          product_class = 2
      elif (product_name == "zapnuer"):
          product_class = 3
      elif (product_name == "zapnuerchick"):
          product_class = 4
      
      targets = np.zeros(4) + 0.01
      
      
      targets[product_class-1] = 0.99
      train_list_ans.append(targets)

# %%
# train_list = []
# train_list_ans = []

# check_type = []

# for (i, img_path) in enumerate(imagePaths):
#       if not (img_path.split(".")[0].split("/")[1] in check_type):
#           check_type.append(img_path.split(".")[0].split("/")[1])
#           print(check_type)
#           img = cv2.imread(img_path)
#           crop_img = to_crop_img(img) 
#           # orange_val = detect_orange(img)
#           # yellow_val = detect_yellow(img)
#           # green_val = detect_green(img)
#           # color_list = np.array([orange_val,yellow_val,green_val])
#           #train_list.append(np.array([(x-min(color_list))/(max(color_list)-min(color_list))  for x in color_list])+0.01)
#           avg_img = avg_in_scale(crop_img)
#           min_avg = min(avg_img)
#           max_avg = max(avg_img)
#           for i in range(len(avg_img)):
#               avg_img[i] = (avg_img[i]-min_avg)/(max_avg-min_avg)
#           train_list.append(avg_img)
#           product_name = img_path.split(".")[0].split("/")[1]
#           product_class = 0
#           if (product_name == "maeyupa"):
#               product_class = 1
#           elif (product_name == "ocean"):
#               product_class = 2
#           elif (product_name == "zapnuer"):
#               product_class = 3
#           elif (product_name == "zapnuerchick"):
#               product_class = 4
          
#           targets = np.zeros(4) + 0.01
          
          
#           targets[product_class-1] = 0.99
#           train_list_ans.append(targets)
#           if(len(check_type)==4):
#               break

# %%
accuracy_each_epochs = []


input_nodes = 105
output_nodes = 4
# hidden_nodes = 21
hidden_nodes = [11]

learning_rate = 0.1
#hidden_layers = 1

weight_each_epochs = []
bias_each_epochs = []

###

n = neuralNetwork(input_nodes,hidden_nodes,output_nodes,learning_rate)

weight_each_epochs.append([])
for i in range(len(hidden_nodes)+1):
  weight_each_epochs[-1].append(n.set_w[i].copy())
bias_each_epochs.append(n.bias.copy())



epochs = 25
for e in range(epochs):
    
    for i in range(len(train_list)):
        inputs =  train_list[i]        
        targets = train_list_ans[i]
        n.train(inputs, targets)
        pass
    pass
    weight_each_epochs.append([])
    for i in range(len(hidden_nodes)+1):
      weight_each_epochs[-1].append(n.set_w[i].copy())
    bias_each_epochs.append(n.bias.copy())


    #test
    
    scorecard = []

    # go through all the records in the test data set
    for  i in range(len(train_list)):
        inputs =  train_list[i]
        ans = np.argmax(train_list_ans[i])
      
               
        outputs = n.query(inputs)
        
        # the index of the highest value corresponds to the label
        label = np.argmax(outputs)

        
        # append correct or incorrect to list
        if (label == ans):
            
            scorecard.append(1)
        else:
            # network's answer doesn't match correct answer, add 0 to scorecard
            scorecard.append(0)
            pass
        pass
    # calculate the performance score, the fraction of correct answers
    scorecard_array = np.asarray(scorecard)
    #print ("performance = ", scorecard_array.sum() /scorecard_array.size*100)
    accuracy_each_epochs.append(scorecard_array.sum() /scorecard_array.size*100)
    # if(scorecard_array.sum() /scorecard_array.size*100 >= 100):
    #   break

plt.plot(np.arange(len(accuracy_each_epochs)),np.array(accuracy_each_epochs)) 
plt.show()
print(max(accuracy_each_epochs))
print(np.argmax(accuracy_each_epochs))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# 100.0
# 14

# %%
n.set_w
# Out:
# array([array([[ 0.10918387, -0.09342865,  0.01072363, ..., -0.26729272,
#         -0.21375603, -0.11885183],
#        [-0.16115046, -0.31733287, -0.19074417, ...,  0.05986984,
#          0.26734433, -0.41157838],
#        [-0.39555551, -0.18176431,  0.20010677, ...,  0.10945968,
#          0.1212759 , -0.60991803],
#        ...,
#        [ 0.12492681,  0.25250479,  0.36899217, ..., -0.03043012,
#          0.04095891,  0.27010346],
#   inflating: test_data/zapnuerchick.23.jpg
#   inflating: test_data/zapnuerchick.24.jpg
#   inflating: test_data/zapnuerchick.25.jpg
#   inflating: test_data/zapnuerchick.26.jpg
#   inflating: test_data/zapnuerchick.33.jpg
#   inflating: test_data/zapnuerchick.34.jpg
#   inflating: test_data/zapnuerchick.35.jpg
#   inflating: test_data/zapnuerchick.36.jpg
#   inflating: test_data/zapnuerchick.37.jpg
#   inflating: test_data/zapnuerchick.38.jpg
#   inflating: test_data/zapnuerchick.45.jpg
#   inflating: test_data/zapnuerchick.46.jpg
#   inflating: test_data/zapnuerchick.47.jpg
#   inflating: test_data/zapnuerchick.48.jpg
#   inflating: test_data/zapnuerchick.49.jpg
#   inflating: test_data/zapnuerchick.50.jpg
#   inflating: test_data/zapnuerchick.57.jpg
#   inflating: test_data/zapnuerchick.58.jpg
#   inflating: test_data/zapnuerchick.59.jpg
#   inflating: test_data/zapnuerchick.60.jpg
#   inflating: test_data/zapnuerchick.61.jpg
#   inflating: test_data/zapnuerchick.62.jpg
#   inflating: test_data/zapnuerchick.69.jpg
#   inflating: test_data/zapnuerchick.70.jpg
#   inflating: test_data/zapnuerchick.71.jpg
#   inflating: test_data/zapnuerchick.72.jpg
#   inflating: test_data/zapnuerchick.73.jpg
#   inflating: test_data/zapnuerchick.74.jpg
#   inflating: test_data/zapnuerchick.81.jpg
#   inflating: test_data/zapnuerchick.82.jpg
#   inflating: test_data/zapnuerchick.83.jpg
#   inflating: test_data/zapnuerchick.84.jpg
#   inflating: test_data/zapnuerchick.85.jpg
#   inflating: test_data/zapnuerchick.86.jpg
#   inflating: test_data/zapnuerchick.9.jpg
#   inflating: test_data/zapnuerchick.93.jpg
#   inflating: test_data/zapnuerchick.94.jpg
#   inflating: test_data/zapnuerchick.95.jpg
#   inflating: test_data/zapnuerchick.96.jpg
#   inflating: test_data/zapnuerchick.97.jpg
#   inflating: test_data/zapnuerchick.98.jpg

# %%
testpath = 'test_data/'
imageTestPaths = [testpath+f for f in listdir(testpath) if isfile(join(testpath, f))]

# %%
test_list = []
test_list_ans = []
for (i, img_path_test) in enumerate(imageTestPaths):
      img = cv2.imread(img_path_test)
      crop_img = to_crop_img(img)
      # orange_val = detect_orange(img)
      # yellow_val = detect_yellow(img)
      # green_val = detect_green(img)
      # color_list = np.array([orange_val,yellow_val,green_val])
      #test_list.append(np.array([(x-min(color_list))/(max(color_list)-min(color_list))  for x in color_list])+0.01)
      avg_img = color_in_scale(crop_img)
      min_avg = min(avg_img)
      max_avg = max(avg_img)
      for i in range(len(avg_img)):
          avg_img[i] = (avg_img[i]-min_avg)/(max_avg-min_avg) 
      test_list.append(avg_img)
      product_name = img_path_test.split(".")[0].split("/")[1]
      product_class = 0
      if (product_name == "maeyupa"):
          product_class = 1
      elif (product_name == "ocean"):
          product_class = 2
      elif (product_name == "zapnuer"):
          product_class = 3
      elif (product_name == "zapnuerchick"):
          product_class = 4

      test_list_ans.append(product_class-1)

# %%
fail_num = 1
scorecard = []
for  i in range(len(test_list)):
    inputs =  test_list[i]
    ans = test_list_ans[i]
  
            
    outputs = n.query(inputs)
    
    # the index of the highest value corresponds to the label
    label = np.argmax(outputs)
    
    # append correct or incorrect to list
    if (label == ans):
        
        scorecard.append(1)
    else:
        # network's answer doesn't match correct answer, add 0 to scorecard
        scorecard.append(0)
        
        print(fail_num,' ',ans,' ',np.transpose(outputs))
        fail_num+=1
        pass
    pass
# calculate the performance score, the fraction of correct answers
scorecard_array = np.asarray(scorecard)
print ("performance = ", scorecard_array.sum() /scorecard_array.size*100)
# Out:
# performance =  100.0

# %%
from google.colab import drive
drive.mount('/content/drive')

# !unzip drive/"My Drive"/korat_sauce/test_after_train7.zip
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archive:  drive/My Drive/korat_sauce/test_after_train7.zip
#    creating: test_after_train7/
#   inflating: test_after_train7/maeyupa.0.jpg
#   inflating: test_after_train7/maeyupa.1.jpg
#   inflating: test_after_train7/maeyupa.10.jpg
#   inflating: test_after_train7/maeyupa.11.jpg
#   inflating: test_after_train7/maeyupa.12.jpg
#   inflating: test_after_train7/maeyupa.13.jpg
#   inflating: test_after_train7/maeyupa.14.jpg
#   inflating: test_after_train7/maeyupa.15.jpg
#   inflating: test_after_train7/maeyupa.16.jpg
#   inflating: test_after_train7/maeyupa.17.jpg
#   inflating: test_after_train7/maeyupa.18.jpg
#   inflating: test_after_train7/maeyupa.19.jpg
#   inflating: test_after_train7/maeyupa.2.jpg
#   inflating: test_after_train7/maeyupa.20.jpg
#   inflating: test_after_train7/maeyupa.21.jpg
#   inflating: test_after_train7/maeyupa.22.jpg
#   inflating: test_after_train7/maeyupa.23.jpg
#   inflating: test_after_train7/maeyupa.24.jpg
#   inflating: test_after_train7/maeyupa.25.jpg
#   inflating: test_after_train7/maeyupa.26.jpg
#   inflating: test_after_train7/maeyupa.27.jpg
#   inflating: test_after_train7/maeyupa.28.jpg
#   inflating: test_after_train7/maeyupa.29.jpg
#   inflating: test_after_train7/maeyupa.3.jpg
#   inflating: test_after_train7/maeyupa.30.jpg
#   inflating: test_after_train7/maeyupa.31.jpg
#   inflating: test_after_train7/maeyupa.32.jpg
#   inflating: test_after_train7/maeyupa.33.jpg
#   inflating: test_after_train7/maeyupa.34.jpg
#   inflating: test_after_train7/maeyupa.35.jpg
#   inflating: test_after_train7/maeyupa.36.jpg
#   inflating: test_after_train7/maeyupa.37.jpg
#   inflating: test_after_train7/maeyupa.38.jpg
#   inflating: test_after_train7/maeyupa.39.jpg
#   inflating: test_after_train7/maeyupa.4.jpg
#   inflating: test_after_train7/maeyupa.40.jpg
#   inflating: test_after_train7/maeyupa.41.jpg
#   inflating: test_after_train7/maeyupa.42.jpg
#   inflating: test_after_train7/maeyupa.43.jpg
#   inflating: test_after_train7/maeyupa.44.jpg
#   inflating: test_after_train7/maeyupa.45.jpg
#   inflating: test_after_train7/maeyupa.46.jpg
#   inflating: test_after_train7/maeyupa.47.jpg
#   inflating: test_after_train7/maeyupa.48.jpg
#   inflating: test_after_train7/maeyupa.49.jpg
#   inflating: test_after_train7/zapnuer.13.jpg
#   inflating: test_after_train7/zapnuer.14.jpg
#   inflating: test_after_train7/zapnuer.15.jpg
#   inflating: test_after_train7/zapnuer.16.jpg
#   inflating: test_after_train7/zapnuer.17.jpg
#   inflating: test_after_train7/zapnuer.18.jpg
#   inflating: test_after_train7/zapnuer.19.jpg
#   inflating: test_after_train7/zapnuer.2.jpg
#   inflating: test_after_train7/zapnuer.20.jpg
#   inflating: test_after_train7/zapnuer.21.jpg
#   inflating: test_after_train7/zapnuer.22.jpg
#   inflating: test_after_train7/zapnuer.23.jpg
#   inflating: test_after_train7/zapnuer.24.jpg
#   inflating: test_after_train7/zapnuer.25.jpg
#   inflating: test_after_train7/zapnuer.26.jpg
#   inflating: test_after_train7/zapnuer.27.jpg
#   inflating: test_after_train7/zapnuer.28.jpg
#   inflating: test_after_train7/zapnuer.29.jpg
#   inflating: test_after_train7/zapnuer.3.jpg
#   inflating: test_after_train7/zapnuer.30.jpg
#   inflating: test_after_train7/zapnuer.31.jpg
#   inflating: test_after_train7/zapnuer.32.jpg
#   inflating: test_after_train7/zapnuer.33.jpg
#   inflating: test_after_train7/zapnuer.34.jpg
#   inflating: test_after_train7/zapnuer.35.jpg
#   inflating: test_after_train7/zapnuer.36.jpg
#   inflating: test_after_train7/zapnuer.37.jpg
#   inflating: test_after_train7/zapnuer.38.jpg
#   inflating: test_after_train7/zapnuer.39.jpg
#   inflating: test_after_train7/zapnuer.4.jpg
#   inflating: test_after_train7/zapnuer.40.jpg
#   inflating: test_after_train7/zapnuer.41.jpg
#   inflating: test_after_train7/zapnuer.42.jpg
#   inflating: test_after_train7/zapnuer.43.jpg
#   inflating: test_after_train7/zapnuer.44.jpg
#   inflating: test_after_train7/zapnuer.45.jpg
#   inflating: test_after_train7/zapnuer.46.jpg
#   inflating: test_after_train7/zapnuer.47.jpg
#   inflating: test_after_train7/zapnuer.48.jpg
#   inflating: test_after_train7/zapnuer.49.jpg
#   inflating: test_after_train7/zapnuer.5.jpg
#   inflating: test_after_train7/zapnuer.6.jpg
#   inflating: test_after_train7/zapnuer.7.jpg
#   inflating: test_after_train7/zapnuer.8.jpg
#   inflating: test_after_train7/zapnuer.9.jpg
#   inflating: test_after_train7/zapnuerchick.0.jpg
#   inflating: test_after_train7/zapnuerchick.1.jpg
#   inflating: test_after_train7/zapnuerchick.10.jpg
#   inflating: test_after_train7/zapnuerchick.11.jpg
#   inflating: test_after_train7/zapnuerchick.12.jpg
#   inflating: test_after_train7/zapnuerchick.13.jpg
#   inflating: test_after_train7/zapnuerchick.14.jpg
#   inflating: test_after_train7/zapnuerchick.15.jpg
#   inflating: test_after_train7/zapnuerchick.16.jpg
#   inflating: test_after_train7/zapnuerchick.17.jpg
#   inflating: test_after_train7/zapnuerchick.18.jpg
#   inflating: test_after_train7/zapnuerchick.19.jpg
#   inflating: test_after_train7/zapnuerchick.2.jpg
#   inflating: test_after_train7/zapnuerchick.20.jpg
#   inflating: test_after_train7/zapnuerchick.21.jpg
#   inflating: test_after_train7/zapnuerchick.22.jpg
#   inflating: test_after_train7/zapnuerchick.23.jpg
#   inflating: test_after_train7/zapnuerchick.24.jpg
#   inflating: test_after_train7/zapnuerchick.25.jpg
#   inflating: test_after_train7/zapnuerchick.26.jpg
#   inflating: test_after_train7/zapnuerchick.27.jpg
#   inflating: test_after_train7/zapnuerchick.28.jpg
#   inflating: test_after_train7/zapnuerchick.29.jpg
#   inflating: test_after_train7/zapnuerchick.3.jpg
#   inflating: test_after_train7/zapnuerchick.30.jpg
#   inflating: test_after_train7/zapnuerchick.31.jpg
#   inflating: test_after_train7/zapnuerchick.32.jpg
#   inflating: test_after_train7/zapnuerchick.33.jpg
#   inflating: test_after_train7/zapnuerchick.34.jpg
#   inflating: test_after_train7/zapnuerchick.35.jpg
#   inflating: test_after_train7/zapnuerchick.36.jpg
#   inflating: test_after_train7/zapnuerchick.37.jpg
#   inflating: test_after_train7/zapnuerchick.38.jpg
#   inflating: test_after_train7/zapnuerchick.39.jpg
#   inflating: test_after_train7/zapnuerchick.4.jpg
#   inflating: test_after_train7/zapnuerchick.40.jpg
#   inflating: test_after_train7/zapnuerchick.41.jpg
#   inflating: test_after_train7/zapnuerchick.42.jpg
#   inflating: test_after_train7/zapnuerchick.43.jpg
#   inflating: test_after_train7/zapnuerchick.44.jpg
#   inflating: test_after_train7/zapnuerchick.45.jpg
#   inflating: test_after_train7/zapnuerchick.46.jpg
#   inflating: test_after_train7/zapnuerchick.47.jpg
#   inflating: test_after_train7/zapnuerchick.48.jpg
#   inflating: test_after_train7/zapnuerchick.49.jpg
#   inflating: test_after_train7/zapnuerchick.5.jpg
#   inflating: test_after_train7/zapnuerchick.50.jpg
#   inflating: test_after_train7/zapnuerchick.51.jpg
#   inflating: test_after_train7/zapnuerchick.52.jpg
#   inflating: test_after_train7/zapnuerchick.53.jpg
#   inflating: test_after_train7/zapnuerchick.54.jpg
#   inflating: test_after_train7/zapnuerchick.6.jpg
#   inflating: test_after_train7/zapnuerchick.7.jpg
#   inflating: test_after_train7/zapnuerchick.8.jpg
#   inflating: test_after_train7/zapnuerchick.9.jpg

# %%
testAfterTrainpath7 = 'test_after_train7/'
imageTestAfterTrainPaths7 = [testAfterTrainpath7+f for f in listdir(testAfterTrainpath7) if isfile(join(testAfterTrainpath7, f))]

# %%
test_after_train_list7 = []
test_after_train_list_ans7 = []
for (i, img_path_test_after_train7) in enumerate(imageTestAfterTrainPaths7):
      img = cv2.imread(img_path_test_after_train7)
      crop_img = to_crop_img(img)
      # orange_val = detect_orange(img)
      # yellow_val = detect_yellow(img)
      # green_val = detect_green(img)
      # color_list = np.array([orange_val,yellow_val,green_val])
      #test_list.append(np.array([(x-min(color_list))/(max(color_list)-min(color_list))  for x in color_list])+0.01) 
      avg_img = color_in_scale(crop_img)
      min_avg = min(avg_img)
      max_avg = max(avg_img)
      for i in range(len(avg_img)):
          avg_img[i] = (avg_img[i]-min_avg)/(max_avg-min_avg) 
      test_after_train_list7.append(avg_img)
      product_name = img_path_test_after_train7.split(".")[0].split("/")[1]
      product_class = 0
      if (product_name == "maeyupa"):
          product_class = 1
      elif (product_name == "ocean"):
          product_class = 2
      elif (product_name == "zapnuer"):
          product_class = 3
      elif (product_name == "zapnuerchick"):
          product_class = 4

      test_after_train_list_ans7.append(product_class-1)

# %%
fail_num = 1
scorecard = []
for  i in range(len(test_after_train_list7)):
    inputs =  test_after_train_list7[i]
    ans = test_after_train_list_ans7[i]
  
            
    outputs = n.query(inputs)
    
    # the index of the highest value corresponds to the label
    label = np.argmax(outputs)
    
    # append correct or incorrect to list
    if (label == ans):
        
        scorecard.append(1)
    else:
        # network's answer doesn't match correct answer, add 0 to scorecard
        scorecard.append(0)
        
        print(fail_num,' ',ans,' ',np.transpose(outputs))
        fail_num+=1
        pass
    pass
# calculate the performance score, the fraction of correct answers
scorecard_array = np.asarray(scorecard)
print ("performance = ", scorecard_array.sum() /scorecard_array.size*100)
# Out:
# performance =  100.0

# %%
from google.colab import drive
drive.mount('/content/drive')

# !unzip drive/"My Drive"/korat_sauce/test_after_train6.zip
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archive:  drive/My Drive/korat_sauce/test_after_train6.zip
#    creating: test_after_train6/
#   inflating: test_after_train6/maeyupa.0.jpg
#   inflating: test_after_train6/maeyupa.1.jpg
#   inflating: test_after_train6/maeyupa.10.jpg
#   inflating: test_after_train6/maeyupa.11.jpg
#   inflating: test_after_train6/maeyupa.12.jpg
#   inflating: test_after_train6/maeyupa.13.jpg
#   inflating: test_after_train6/maeyupa.14.jpg
#   inflating: test_after_train6/maeyupa.15.jpg
#   inflating: test_after_train6/maeyupa.16.jpg
#   inflating: test_after_train6/maeyupa.17.jpg
#   inflating: test_after_train6/maeyupa.18.jpg
#   inflating: test_after_train6/maeyupa.19.jpg
#   inflating: test_after_train6/maeyupa.2.jpg
#   inflating: test_after_train6/maeyupa.20.jpg
#   inflating: test_after_train6/maeyupa.21.jpg
#   inflating: test_after_train6/maeyupa.22.jpg
#   inflating: test_after_train6/maeyupa.23.jpg
#   inflating: test_after_train6/maeyupa.24.jpg
#   inflating: test_after_train6/maeyupa.25.jpg
#   inflating: test_after_train6/maeyupa.26.jpg
#   inflating: test_after_train6/maeyupa.27.jpg
#   inflating: test_after_train6/maeyupa.28.jpg
#   inflating: test_after_train6/maeyupa.29.jpg
#   inflating: test_after_train6/maeyupa.3.jpg
#   inflating: test_after_train6/maeyupa.30.jpg
#   inflating: test_after_train6/maeyupa.31.jpg
#   inflating: test_after_train6/maeyupa.32.jpg
#   inflating: test_after_train6/maeyupa.33.jpg
#   inflating: test_after_train6/maeyupa.34.jpg
#   inflating: test_after_train6/maeyupa.35.jpg
#   inflating: test_after_train6/maeyupa.36.jpg
#   inflating: test_after_train6/maeyupa.37.jpg
#   inflating: test_after_train6/maeyupa.38.jpg
#   inflating: test_after_train6/maeyupa.39.jpg
#   inflating: test_after_train6/maeyupa.4.jpg
#   inflating: test_after_train6/maeyupa.40.jpg
#   inflating: test_after_train6/maeyupa.41.jpg
#   inflating: test_after_train6/zapnuerchick.57.jpg
#   inflating: test_after_train6/zapnuerchick.58.jpg
#   inflating: test_after_train6/zapnuerchick.59.jpg
#   inflating: test_after_train6/zapnuerchick.6.jpg
#   inflating: test_after_train6/zapnuerchick.60.jpg
#   inflating: test_after_train6/zapnuerchick.61.jpg
#   inflating: test_after_train6/zapnuerchick.62.jpg
#   inflating: test_after_train6/zapnuerchick.63.jpg
#   inflating: test_after_train6/zapnuerchick.64.jpg
#   inflating: test_after_train6/zapnuerchick.65.jpg
#   inflating: test_after_train6/zapnuerchick.66.jpg
#   inflating: test_after_train6/zapnuerchick.67.jpg
#   inflating: test_after_train6/zapnuerchick.68.jpg
#   inflating: test_after_train6/zapnuerchick.69.jpg
#   inflating: test_after_train6/zapnuerchick.7.jpg
#   inflating: test_after_train6/zapnuerchick.70.jpg
#   inflating: test_after_train6/zapnuerchick.71.jpg
#   inflating: test_after_train6/zapnuerchick.72.jpg
#   inflating: test_after_train6/zapnuerchick.73.jpg
#   inflating: test_after_train6/zapnuerchick.74.jpg
#   inflating: test_after_train6/zapnuerchick.75.jpg
#   inflating: test_after_train6/zapnuerchick.76.jpg
#   inflating: test_after_train6/zapnuerchick.77.jpg
#   inflating: test_after_train6/zapnuerchick.78.jpg
#   inflating: test_after_train6/zapnuerchick.8.jpg
#   inflating: test_after_train6/zapnuerchick.9.jpg

# %%
testAfterTrainpath6 = 'test_after_train6/'
imageTestAfterTrainPaths6 = [testAfterTrainpath6+f for f in listdir(testAfterTrainpath6) if isfile(join(testAfterTrainpath6, f))]

# %%
test_after_train_list6 = []
test_after_train_list_ans6 = []
for (i, img_path_test_after_train6) in enumerate(imageTestAfterTrainPaths6):
      img = cv2.imread(img_path_test_after_train6)
      crop_img = to_crop_img(img)
      # orange_val = detect_orange(img)
      # yellow_val = detect_yellow(img)
      # green_val = detect_green(img)
      # color_list = np.array([orange_val,yellow_val,green_val])
      #test_list.append(np.array([(x-min(color_list))/(max(color_list)-min(color_list))  for x in color_list])+0.01) 
      avg_img = color_in_scale(crop_img)
      min_avg = min(avg_img)
      max_avg = max(avg_img)
      for i in range(len(avg_img)):
          avg_img[i] = (avg_img[i]-min_avg)/(max_avg-min_avg) 
      test_after_train_list6.append(avg_img)
      product_name = img_path_test_after_train6.split(".")[0].split("/")[1]
      product_class = 0
      if (product_name == "maeyupa"):
          product_class = 1
      elif (product_name == "ocean"):
          product_class = 2
      elif (product_name == "zapnuer"):
          product_class = 3
      elif (product_name == "zapnuerchick"):
          product_class = 4

      test_after_train_list_ans6.append(product_class-1)

# %%
fail_num = 1
scorecard = []
for  i in range(len(test_after_train_list6)):
    inputs =  test_after_train_list6[i]
    ans = test_after_train_list_ans6[i]
  
            
    outputs = n.query(inputs)
    
    # the index of the highest value corresponds to the label
    label = np.argmax(outputs)
    
    # append correct or incorrect to list
    if (label == ans):
        
        scorecard.append(1)
    else:
        # network's answer doesn't match correct answer, add 0 to scorecard
        scorecard.append(0)
        
        print(fail_num,' ',ans,' ',np.transpose(outputs))
        fail_num+=1
        pass
    pass
# calculate the performance score, the fraction of correct answers
scorecard_array = np.asarray(scorecard)
print ("performance = ", scorecard_array.sum() /scorecard_array.size*100)
# Out:
# 1   3   [[0.00264747 0.68791862 0.04009977 0.46881996]]
# performance =  99.59514170040485

# %%
from google.colab import drive
drive.mount('/content/drive')

# !unzip drive/"My Drive"/korat_sauce/test_after_train5.zip
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archive:  drive/My Drive/korat_sauce/test_after_train5.zip
#    creating: test_after_train5/
#   inflating: test_after_train5/maeyupa.0.jpg
#   inflating: test_after_train5/maeyupa.1.jpg
#   inflating: test_after_train5/maeyupa.10.jpg
#   inflating: test_after_train5/maeyupa.11.jpg
#   inflating: test_after_train5/maeyupa.12.jpg
#   inflating: test_after_train5/maeyupa.13.jpg
#   inflating: test_after_train5/maeyupa.14.jpg
#   inflating: test_after_train5/maeyupa.15.jpg
#   inflating: test_after_train5/maeyupa.16.jpg
#   inflating: test_after_train5/maeyupa.17.jpg
#   inflating: test_after_train5/maeyupa.18.jpg
#   inflating: test_after_train5/maeyupa.19.jpg
#   inflating: test_after_train5/maeyupa.2.jpg
#   inflating: test_after_train5/maeyupa.20.jpg
#   inflating: test_after_train5/maeyupa.21.jpg
#   inflating: test_after_train5/maeyupa.22.jpg
#   inflating: test_after_train5/maeyupa.23.jpg
#   inflating: test_after_train5/maeyupa.24.jpg
#   inflating: test_after_train5/maeyupa.25.jpg
#   inflating: test_after_train5/maeyupa.26.jpg
#   inflating: test_after_train5/maeyupa.27.jpg
#   inflating: test_after_train5/maeyupa.28.jpg
#   inflating: test_after_train5/maeyupa.29.jpg
#   inflating: test_after_train5/maeyupa.3.jpg
#   inflating: test_after_train5/maeyupa.30.jpg
#   inflating: test_after_train5/maeyupa.31.jpg
#   inflating: test_after_train5/maeyupa.32.jpg
#   inflating: test_after_train5/maeyupa.33.jpg
#   inflating: test_after_train5/maeyupa.34.jpg
#   inflating: test_after_train5/maeyupa.35.jpg
#   inflating: test_after_train5/maeyupa.36.jpg
#   inflating: test_after_train5/maeyupa.37.jpg
#   inflating: test_after_train5/maeyupa.38.jpg
#   inflating: test_after_train5/maeyupa.39.jpg
#   inflating: test_after_train5/maeyupa.4.jpg
#   inflating: test_after_train5/maeyupa.40.jpg
#   inflating: test_after_train5/maeyupa.41.jpg
#   inflating: test_after_train5/maeyupa.5.jpg
#   inflating: test_after_train5/maeyupa.6.jpg
#   inflating: test_after_train5/maeyupa.7.jpg
#   inflating: test_after_train5/maeyupa.8.jpg
#   inflating: test_after_train5/maeyupa.9.jpg
#   inflating: test_after_train5/ocean.0.jpg
#   inflating: test_after_train5/ocean.1.jpg
#   inflating: test_after_train5/ocean.10.jpg
#   inflating: test_after_train5/ocean.11.jpg
#   inflating: test_after_train5/ocean.12.jpg
#   inflating: test_after_train5/ocean.13.jpg
#   inflating: test_after_train5/ocean.14.jpg
#   inflating: test_after_train5/ocean.15.jpg
#   inflating: test_after_train5/ocean.16.jpg
#   inflating: test_after_train5/ocean.17.jpg
#   inflating: test_after_train5/ocean.18.jpg
#   inflating: test_after_train5/ocean.19.jpg
#   inflating: test_after_train5/ocean.2.jpg
#   inflating: test_after_train5/ocean.20.jpg
#   inflating: test_after_train5/ocean.21.jpg
#   inflating: test_after_train5/ocean.22.jpg
#   inflating: test_after_train5/ocean.23.jpg
#   inflating: test_after_train5/ocean.24.jpg
#   inflating: test_after_train5/ocean.25.jpg
#   inflating: test_after_train5/ocean.26.jpg
#   inflating: test_after_train5/ocean.27.jpg
#   inflating: test_after_train5/ocean.28.jpg
#   inflating: test_after_train5/ocean.29.jpg
#   inflating: test_after_train5/ocean.3.jpg
#   inflating: test_after_train5/ocean.30.jpg
#   inflating: test_after_train5/ocean.31.jpg
#   inflating: test_after_train5/ocean.4.jpg
#   inflating: test_after_train5/ocean.5.jpg
#   inflating: test_after_train5/ocean.6.jpg
#   inflating: test_after_train5/ocean.7.jpg
#   inflating: test_after_train5/ocean.8.jpg
#   inflating: test_after_train5/ocean.9.jpg
#   inflating: test_after_train5/zapnuer.0.jpg
#   inflating: test_after_train5/zapnuer.1.jpg
#   inflating: test_after_train5/zapnuer.10.jpg
#   inflating: test_after_train5/zapnuer.11.jpg
#   inflating: test_after_train5/zapnuer.12.jpg
#   inflating: test_after_train5/zapnuer.13.jpg
#   inflating: test_after_train5/zapnuer.14.jpg
#   inflating: test_after_train5/zapnuer.15.jpg
#   inflating: test_after_train5/zapnuer.16.jpg
#   inflating: test_after_train5/zapnuer.17.jpg
#   inflating: test_after_train5/zapnuer.18.jpg
#   inflating: test_after_train5/zapnuer.19.jpg
#   inflating: test_after_train5/zapnuer.2.jpg
#   inflating: test_after_train5/zapnuer.20.jpg
#   inflating: test_after_train5/zapnuer.21.jpg
#   inflating: test_after_train5/zapnuer.22.jpg
#   inflating: test_after_train5/zapnuer.23.jpg
#   inflating: test_after_train5/zapnuer.24.jpg
#   inflating: test_after_train5/zapnuer.25.jpg
#   inflating: test_after_train5/zapnuer.26.jpg
#   inflating: test_after_train5/zapnuer.27.jpg
#   inflating: test_after_train5/zapnuer.28.jpg
#   inflating: test_after_train5/zapnuer.29.jpg
#   inflating: test_after_train5/zapnuer.3.jpg
#   inflating: test_after_train5/zapnuer.30.jpg
#   inflating: test_after_train5/zapnuer.31.jpg
#   inflating: test_after_train5/zapnuer.32.jpg
#   inflating: test_after_train5/zapnuer.33.jpg
#   inflating: test_after_train5/zapnuer.34.jpg
#   inflating: test_after_train5/zapnuer.35.jpg
#   inflating: test_after_train5/zapnuer.36.jpg
#   inflating: test_after_train5/zapnuer.37.jpg
#   inflating: test_after_train5/zapnuer.38.jpg
#   inflating: test_after_train5/zapnuer.39.jpg
#   inflating: test_after_train5/zapnuer.4.jpg
#   inflating: test_after_train5/zapnuer.40.jpg
#   inflating: test_after_train5/zapnuer.41.jpg
#   inflating: test_after_train5/zapnuer.5.jpg
#   inflating: test_after_train5/zapnuer.6.jpg
#   inflating: test_after_train5/zapnuer.7.jpg
#   inflating: test_after_train5/zapnuer.8.jpg
#   inflating: test_after_train5/zapnuer.9.jpg
#   inflating: test_after_train5/zapnuerchick.0.jpg
#   inflating: test_after_train5/zapnuerchick.1.jpg
#   inflating: test_after_train5/zapnuerchick.10.jpg
#   inflating: test_after_train5/zapnuerchick.11.jpg
#   inflating: test_after_train5/zapnuerchick.12.jpg
#   inflating: test_after_train5/zapnuerchick.13.jpg
#   inflating: test_after_train5/zapnuerchick.14.jpg
#   inflating: test_after_train5/zapnuerchick.15.jpg
#   inflating: test_after_train5/zapnuerchick.16.jpg
#   inflating: test_after_train5/zapnuerchick.17.jpg
#   inflating: test_after_train5/zapnuerchick.18.jpg
#   inflating: test_after_train5/zapnuerchick.19.jpg
#   inflating: test_after_train5/zapnuerchick.2.jpg
#   inflating: test_after_train5/zapnuerchick.20.jpg
#   inflating: test_after_train5/zapnuerchick.21.jpg
#   inflating: test_after_train5/zapnuerchick.22.jpg
#   inflating: test_after_train5/zapnuerchick.23.jpg
#   inflating: test_after_train5/zapnuerchick.24.jpg
#   inflating: test_after_train5/zapnuerchick.25.jpg
#   inflating: test_after_train5/zapnuerchick.26.jpg
#   inflating: test_after_train5/zapnuerchick.27.jpg
#   inflating: test_after_train5/zapnuerchick.28.jpg
#   inflating: test_after_train5/zapnuerchick.29.jpg
#   inflating: test_after_train5/zapnuerchick.3.jpg
#   inflating: test_after_train5/zapnuerchick.30.jpg
#   inflating: test_after_train5/zapnuerchick.31.jpg
#   inflating: test_after_train5/zapnuerchick.32.jpg
#   inflating: test_after_train5/zapnuerchick.33.jpg
#   inflating: test_after_train5/zapnuerchick.34.jpg
#   inflating: test_after_train5/zapnuerchick.35.jpg
#   inflating: test_after_train5/zapnuerchick.36.jpg
#   inflating: test_after_train5/zapnuerchick.37.jpg
#   inflating: test_after_train5/zapnuerchick.38.jpg
#   inflating: test_after_train5/zapnuerchick.39.jpg
#   inflating: test_after_train5/zapnuerchick.4.jpg
#   inflating: test_after_train5/zapnuerchick.40.jpg
#   inflating: test_after_train5/zapnuerchick.41.jpg
#   inflating: test_after_train5/zapnuerchick.42.jpg
#   inflating: test_after_train5/zapnuerchick.43.jpg
#   inflating: test_after_train5/zapnuerchick.44.jpg
#   inflating: test_after_train5/zapnuerchick.45.jpg
#   inflating: test_after_train5/zapnuerchick.5.jpg
#   inflating: test_after_train5/zapnuerchick.6.jpg
#   inflating: test_after_train5/zapnuerchick.7.jpg
#   inflating: test_after_train5/zapnuerchick.8.jpg
#   inflating: test_after_train5/zapnuerchick.9.jpg

# %%
testAfterTrainpath5 = 'test_after_train5/'
imageTestAfterTrainPaths5 = [testAfterTrainpath5+f for f in listdir(testAfterTrainpath5) if isfile(join(testAfterTrainpath5, f))]

# %%
test_after_train_list5 = []
test_after_train_list_ans5 = []
for (i, img_path_test_after_train5) in enumerate(imageTestAfterTrainPaths5):
      img = cv2.imread(img_path_test_after_train5)
      crop_img = to_crop_img(img)
      # orange_val = detect_orange(img)
      # yellow_val = detect_yellow(img)
      # green_val = detect_green(img)
      # color_list = np.array([orange_val,yellow_val,green_val])
      #test_list.append(np.array([(x-min(color_list))/(max(color_list)-min(color_list))  for x in color_list])+0.01) 
      avg_img = color_in_scale(crop_img)
      min_avg = min(avg_img)
      max_avg = max(avg_img)
      for i in range(len(avg_img)):
          avg_img[i] = (avg_img[i]-min_avg)/(max_avg-min_avg) 
      test_after_train_list5.append(avg_img)
      product_name = img_path_test_after_train5.split(".")[0].split("/")[1]
      product_class = 0
      if (product_name == "maeyupa"):
          product_class = 1
      elif (product_name == "ocean"):
          product_class = 2
      elif (product_name == "zapnuer"):
          product_class = 3
      elif (product_name == "zapnuerchick"):
          product_class = 4

      test_after_train_list_ans5.append(product_class-1)

# %%
fail_num = 1
scorecard = []
for  i in range(len(test_after_train_list5)):
    inputs =  test_after_train_list5[i]
    ans = test_after_train_list_ans5[i]
  
            
    outputs = n.query(inputs)
    
    # the index of the highest value corresponds to the label
    label = np.argmax(outputs)
    
    # append correct or incorrect to list
    if (label == ans):
        
        scorecard.append(1)
    else:
        # network's answer doesn't match correct answer, add 0 to scorecard
        scorecard.append(0)
        
        print(fail_num,' ',ans,' ',np.transpose(outputs))
        fail_num+=1
        pass
    pass
# calculate the performance score, the fraction of correct answers
scorecard_array = np.asarray(scorecard)
print ("performance = ", scorecard_array.sum() /scorecard_array.size*100)
# Out:
# 1   1   [[0.68294886 0.07318719 0.05315336 0.01852951]]
# 2   1   [[0.77401811 0.06573062 0.04480715 0.00946945]]
# 3   1   [[0.65146983 0.14580421 0.03613026 0.00832516]]
# 4   1   [[0.72145719 0.08693665 0.04452882 0.00882722]]
# 5   1   [[0.47393163 0.16588632 0.0200815  0.01960955]]
# 6   1   [[0.89791478 0.03564069 0.01824306 0.01816032]]
# 7   1   [[0.46885988 0.19205946 0.04843532 0.00624539]]
# 8   1   [[0.87994186 0.03795422 0.03093589 0.01243132]]
# 9   1   [[0.70327001 0.05920354 0.05448734 0.02406338]]
# 10   1   [[0.67037101 0.10495618 0.04521496 0.00909988]]
# performance =  93.82716049382715

# %%
from google.colab import drive
drive.mount('/content/drive')

# !unzip drive/"My Drive"/korat_sauce/test_after_train7_5.zip
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archive:  drive/My Drive/korat_sauce/test_after_train7_5.zip
#    creating: test_after_train7_5/
#   inflating: test_after_train7_5/maeyupa.0.jpg
#   inflating: test_after_train7_5/maeyupa.1.jpg
#   inflating: test_after_train7_5/maeyupa.10.jpg
#   inflating: test_after_train7_5/maeyupa.100.jpg
#   inflating: test_after_train7_5/maeyupa.101.jpg
#   inflating: test_after_train7_5/maeyupa.102.jpg
#   inflating: test_after_train7_5/maeyupa.103.jpg
#   inflating: test_after_train7_5/maeyupa.104.jpg
#   inflating: test_after_train7_5/maeyupa.105.jpg
#   inflating: test_after_train7_5/maeyupa.106.jpg
#   inflating: test_after_train7_5/maeyupa.107.jpg
#   inflating: test_after_train7_5/maeyupa.108.jpg
#   inflating: test_after_train7_5/maeyupa.109.jpg
#   inflating: test_after_train7_5/maeyupa.11.jpg
#   inflating: test_after_train7_5/maeyupa.110.jpg
#   inflating: test_after_train7_5/maeyupa.111.jpg
#   inflating: test_after_train7_5/maeyupa.112.jpg
#   inflating: test_after_train7_5/maeyupa.113.jpg
#   inflating: test_after_train7_5/maeyupa.114.jpg
#   inflating: test_after_train7_5/maeyupa.115.jpg
#   inflating: test_after_train7_5/maeyupa.116.jpg
#   inflating: test_after_train7_5/maeyupa.117.jpg
#   inflating: test_after_train7_5/maeyupa.118.jpg
#   inflating: test_after_train7_5/maeyupa.119.jpg
#   inflating: test_after_train7_5/maeyupa.12.jpg
#   inflating: test_after_train7_5/maeyupa.120.jpg
#   inflating: test_after_train7_5/maeyupa.121.jpg
#   inflating: test_after_train7_5/maeyupa.122.jpg
#   inflating: test_after_train7_5/maeyupa.123.jpg
#   inflating: test_after_train7_5/maeyupa.124.jpg
#   inflating: test_after_train7_5/maeyupa.125.jpg
#   inflating: test_after_train7_5/maeyupa.126.jpg
#   inflating: test_after_train7_5/maeyupa.127.jpg
#   inflating: test_after_train7_5/maeyupa.128.jpg
#   inflating: test_after_train7_5/maeyupa.129.jpg
#   inflating: test_after_train7_5/maeyupa.13.jpg
#   inflating: test_after_train7_5/maeyupa.130.jpg
#   inflating: test_after_train7_5/maeyupa.131.jpg
#   inflating: test_after_train7_5/maeyupa.132.jpg
#   inflating: test_after_train7_5/maeyupa.133.jpg
#   inflating: test_after_train7_5/maeyupa.134.jpg
#   inflating: test_after_train7_5/maeyupa.135.jpg
#   inflating: test_after_train7_5/maeyupa.136.jpg
#   inflating: test_after_train7_5/maeyupa.137.jpg
#   inflating: test_after_train7_5/maeyupa.138.jpg
#   inflating: test_after_train7_5/maeyupa.139.jpg
#   inflating: test_after_train7_5/maeyupa.14.jpg
#   inflating: test_after_train7_5/maeyupa.140.jpg
#   inflating: test_after_train7_5/maeyupa.141.jpg
#   inflating: test_after_train7_5/maeyupa.142.jpg
#   inflating: test_after_train7_5/maeyupa.143.jpg
#   inflating: test_after_train7_5/maeyupa.144.jpg
#   inflating: test_after_train7_5/maeyupa.145.jpg
#   inflating: test_after_train7_5/maeyupa.146.jpg
#   inflating: test_after_train7_5/maeyupa.147.jpg
#   inflating: test_after_train7_5/maeyupa.148.jpg
#   inflating: test_after_train7_5/maeyupa.149.jpg
#   inflating: test_after_train7_5/maeyupa.15.jpg
#   inflating: test_after_train7_5/maeyupa.150.jpg
#   inflating: test_after_train7_5/maeyupa.151.jpg
#   inflating: test_after_train7_5/maeyupa.152.jpg
#   inflating: test_after_train7_5/maeyupa.153.jpg
#   inflating: test_after_train7_5/maeyupa.154.jpg
#   inflating: test_after_train7_5/maeyupa.155.jpg
#   inflating: test_after_train7_5/maeyupa.156.jpg
#   inflating: test_after_train7_5/maeyupa.157.jpg
#   inflating: test_after_train7_5/maeyupa.158.jpg
#   inflating: test_after_train7_5/maeyupa.159.jpg
#   inflating: test_after_train7_5/maeyupa.16.jpg
#   inflating: test_after_train7_5/maeyupa.160.jpg
#   inflating: test_after_train7_5/maeyupa.161.jpg
#   inflating: test_after_train7_5/maeyupa.162.jpg
#   inflating: test_after_train7_5/maeyupa.163.jpg
#   inflating: test_after_train7_5/maeyupa.164.jpg
#   inflating: test_after_train7_5/maeyupa.165.jpg
#   inflating: test_after_train7_5/maeyupa.166.jpg
#   inflating: test_after_train7_5/maeyupa.167.jpg
#   inflating: test_after_train7_5/maeyupa.168.jpg
#   inflating: test_after_train7_5/maeyupa.169.jpg
#   inflating: test_after_train7_5/maeyupa.17.jpg
#   inflating: test_after_train7_5/maeyupa.170.jpg
#   inflating: test_after_train7_5/maeyupa.171.jpg
#   inflating: test_after_train7_5/maeyupa.172.jpg
#   inflating: test_after_train7_5/maeyupa.173.jpg
#   inflating: test_after_train7_5/maeyupa.174.jpg
#   inflating: test_after_train7_5/maeyupa.175.jpg
#   inflating: test_after_train7_5/maeyupa.176.jpg
#   inflating: test_after_train7_5/maeyupa.177.jpg
#   inflating: test_after_train7_5/maeyupa.178.jpg
#   inflating: test_after_train7_5/maeyupa.179.jpg
#   inflating: test_after_train7_5/maeyupa.18.jpg
#   inflating: test_after_train7_5/maeyupa.180.jpg
#   inflating: test_after_train7_5/maeyupa.181.jpg
#   inflating: test_after_train7_5/maeyupa.182.jpg
#   inflating: test_after_train7_5/maeyupa.183.jpg
#   inflating: test_after_train7_5/maeyupa.184.jpg
#   inflating: test_after_train7_5/maeyupa.185.jpg
#   inflating: test_after_train7_5/maeyupa.186.jpg
#   inflating: test_after_train7_5/maeyupa.187.jpg
#   inflating: test_after_train7_5/maeyupa.188.jpg
#   inflating: test_after_train7_5/maeyupa.189.jpg
#   inflating: test_after_train7_5/maeyupa.19.jpg
#   inflating: test_after_train7_5/maeyupa.190.jpg
#   inflating: test_after_train7_5/maeyupa.191.jpg
#   inflating: test_after_train7_5/maeyupa.192.jpg
#   inflating: test_after_train7_5/maeyupa.193.jpg
#   inflating: test_after_train7_5/maeyupa.194.jpg
#   inflating: test_after_train7_5/maeyupa.195.jpg
#   inflating: test_after_train7_5/maeyupa.196.jpg
#   inflating: test_after_train7_5/maeyupa.197.jpg
#   inflating: test_after_train7_5/maeyupa.198.jpg
#   inflating: test_after_train7_5/maeyupa.199.jpg
#   inflating: test_after_train7_5/maeyupa.2.jpg
#   inflating: test_after_train7_5/maeyupa.20.jpg
#   inflating: test_after_train7_5/maeyupa.200.jpg
#   inflating: test_after_train7_5/maeyupa.201.jpg
#   inflating: test_after_train7_5/maeyupa.202.jpg
#   inflating: test_after_train7_5/maeyupa.203.jpg
#   inflating: test_after_train7_5/maeyupa.204.jpg
#   inflating: test_after_train7_5/maeyupa.205.jpg
#   inflating: test_after_train7_5/maeyupa.206.jpg
#   inflating: test_after_train7_5/maeyupa.207.jpg
#   inflating: test_after_train7_5/maeyupa.208.jpg
#   inflating: test_after_train7_5/maeyupa.209.jpg
#   inflating: test_after_train7_5/maeyupa.21.jpg
#   inflating: test_after_train7_5/maeyupa.210.jpg
#   inflating: test_after_train7_5/maeyupa.211.jpg
#   inflating: test_after_train7_5/maeyupa.212.jpg
#   inflating: test_after_train7_5/maeyupa.213.jpg
#   inflating: test_after_train7_5/maeyupa.214.jpg
#   inflating: test_after_train7_5/maeyupa.215.jpg
#   inflating: test_after_train7_5/maeyupa.216.jpg
#   inflating: test_after_train7_5/maeyupa.217.jpg
#   inflating: test_after_train7_5/maeyupa.218.jpg
#   inflating: test_after_train7_5/maeyupa.219.jpg
#   inflating: test_after_train7_5/maeyupa.22.jpg
#   inflating: test_after_train7_5/maeyupa.220.jpg
#   inflating: test_after_train7_5/maeyupa.221.jpg
#   inflating: test_after_train7_5/maeyupa.222.jpg
#   inflating: test_after_train7_5/maeyupa.223.jpg
#   inflating: test_after_train7_5/maeyupa.224.jpg
#   inflating: test_after_train7_5/maeyupa.225.jpg
#   inflating: test_after_train7_5/maeyupa.226.jpg
#   inflating: test_after_train7_5/maeyupa.227.jpg
#   inflating: test_after_train7_5/maeyupa.228.jpg
#   inflating: test_after_train7_5/maeyupa.229.jpg
#   inflating: test_after_train7_5/maeyupa.23.jpg
#   inflating: test_after_train7_5/maeyupa.230.jpg
#   inflating: test_after_train7_5/maeyupa.231.jpg
#   inflating: test_after_train7_5/maeyupa.232.jpg
#   inflating: test_after_train7_5/maeyupa.233.jpg
#   inflating: test_after_train7_5/maeyupa.234.jpg
#   inflating: test_after_train7_5/maeyupa.235.jpg
#   inflating: test_after_train7_5/maeyupa.236.jpg
#   inflating: test_after_train7_5/maeyupa.237.jpg
#   inflating: test_after_train7_5/maeyupa.238.jpg
#   inflating: test_after_train7_5/maeyupa.239.jpg
#   inflating: test_after_train7_5/maeyupa.24.jpg
#   inflating: test_after_train7_5/maeyupa.240.jpg
#   inflating: test_after_train7_5/maeyupa.241.jpg
#   inflating: test_after_train7_5/maeyupa.242.jpg
#   inflating: test_after_train7_5/maeyupa.243.jpg
#   inflating: test_after_train7_5/maeyupa.244.jpg
#   inflating: test_after_train7_5/maeyupa.245.jpg
#   inflating: test_after_train7_5/maeyupa.246.jpg
#   inflating: test_after_train7_5/maeyupa.247.jpg
#   inflating: test_after_train7_5/maeyupa.248.jpg
#   inflating: test_after_train7_5/maeyupa.249.jpg
#   inflating: test_after_train7_5/maeyupa.25.jpg
#   inflating: test_after_train7_5/maeyupa.250.jpg
#   inflating: test_after_train7_5/maeyupa.251.jpg
#   inflating: test_after_train7_5/maeyupa.252.jpg
#   inflating: test_after_train7_5/maeyupa.253.jpg
#   inflating: test_after_train7_5/maeyupa.254.jpg
#   inflating: test_after_train7_5/maeyupa.255.jpg
#   inflating: test_after_train7_5/maeyupa.256.jpg
#   inflating: test_after_train7_5/maeyupa.257.jpg
#   inflating: test_after_train7_5/maeyupa.258.jpg
#   inflating: test_after_train7_5/maeyupa.259.jpg
#   inflating: test_after_train7_5/maeyupa.26.jpg
#   inflating: test_after_train7_5/maeyupa.260.jpg
#   inflating: test_after_train7_5/maeyupa.261.jpg
#   inflating: test_after_train7_5/maeyupa.262.jpg
#   inflating: test_after_train7_5/maeyupa.263.jpg
#   inflating: test_after_train7_5/maeyupa.264.jpg
#   inflating: test_after_train7_5/maeyupa.265.jpg
#   inflating: test_after_train7_5/maeyupa.266.jpg
#   inflating: test_after_train7_5/maeyupa.267.jpg
#   inflating: test_after_train7_5/maeyupa.268.jpg
#   inflating: test_after_train7_5/maeyupa.269.jpg
#   inflating: test_after_train7_5/maeyupa.27.jpg
#   inflating: test_after_train7_5/maeyupa.270.jpg
#   inflating: test_after_train7_5/maeyupa.271.jpg
#   inflating: test_after_train7_5/maeyupa.272.jpg
#   inflating: test_after_train7_5/maeyupa.273.jpg
#   inflating: test_after_train7_5/maeyupa.274.jpg
#   inflating: test_after_train7_5/maeyupa.28.jpg
#   inflating: test_after_train7_5/maeyupa.29.jpg
#   inflating: test_after_train7_5/maeyupa.3.jpg
#   inflating: test_after_train7_5/maeyupa.30.jpg
#   inflating: test_after_train7_5/maeyupa.31.jpg
#   inflating: test_after_train7_5/maeyupa.32.jpg
#   inflating: test_after_train7_5/maeyupa.33.jpg
#   inflating: test_after_train7_5/maeyupa.34.jpg
#   inflating: test_after_train7_5/maeyupa.35.jpg
#   inflating: test_after_train7_5/maeyupa.36.jpg
#   inflating: test_after_train7_5/maeyupa.37.jpg
#   inflating: test_after_train7_5/maeyupa.38.jpg
#   inflating: test_after_train7_5/maeyupa.39.jpg
#   inflating: test_after_train7_5/maeyupa.4.jpg
#   inflating: test_after_train7_5/maeyupa.40.jpg
#   inflating: test_after_train7_5/maeyupa.41.jpg
#   inflating: test_after_train7_5/maeyupa.42.jpg
#   inflating: test_after_train7_5/maeyupa.43.jpg
#   inflating: test_after_train7_5/maeyupa.44.jpg
#   inflating: test_after_train7_5/maeyupa.45.jpg
#   inflating: test_after_train7_5/maeyupa.46.jpg
#   inflating: test_after_train7_5/maeyupa.47.jpg
#   inflating: test_after_train7_5/maeyupa.48.jpg
#   inflating: test_after_train7_5/maeyupa.49.jpg
#   inflating: test_after_train7_5/maeyupa.5.jpg
#   inflating: test_after_train7_5/maeyupa.50.jpg
#   inflating: test_after_train7_5/maeyupa.51.jpg
#   inflating: test_after_train7_5/maeyupa.52.jpg
#   inflating: test_after_train7_5/maeyupa.53.jpg
#   inflating: test_after_train7_5/maeyupa.54.jpg
#   inflating: test_after_train7_5/maeyupa.55.jpg
#   inflating: test_after_train7_5/maeyupa.56.jpg
#   inflating: test_after_train7_5/maeyupa.57.jpg
#   inflating: test_after_train7_5/maeyupa.58.jpg
#   inflating: test_after_train7_5/maeyupa.59.jpg
#   inflating: test_after_train7_5/maeyupa.6.jpg
#   inflating: test_after_train7_5/maeyupa.60.jpg
#   inflating: test_after_train7_5/maeyupa.61.jpg
#   inflating: test_after_train7_5/maeyupa.62.jpg
#   inflating: test_after_train7_5/maeyupa.63.jpg
#   inflating: test_after_train7_5/maeyupa.64.jpg
#   inflating: test_after_train7_5/maeyupa.65.jpg
#   inflating: test_after_train7_5/maeyupa.66.jpg
#   inflating: test_after_train7_5/maeyupa.67.jpg
#   inflating: test_after_train7_5/maeyupa.68.jpg
#   inflating: test_after_train7_5/maeyupa.69.jpg
#   inflating: test_after_train7_5/maeyupa.7.jpg
#   inflating: test_after_train7_5/maeyupa.70.jpg
#   inflating: test_after_train7_5/maeyupa.71.jpg
#   inflating: test_after_train7_5/maeyupa.72.jpg
#   inflating: test_after_train7_5/maeyupa.73.jpg
#   inflating: test_after_train7_5/maeyupa.74.jpg
#   inflating: test_after_train7_5/maeyupa.75.jpg
#   inflating: test_after_train7_5/maeyupa.76.jpg
#   inflating: test_after_train7_5/maeyupa.77.jpg
#   inflating: test_after_train7_5/maeyupa.78.jpg
#   inflating: test_after_train7_5/maeyupa.79.jpg
#   inflating: test_after_train7_5/maeyupa.8.jpg
#   inflating: test_after_train7_5/maeyupa.80.jpg
#   inflating: test_after_train7_5/maeyupa.81.jpg
#   inflating: test_after_train7_5/maeyupa.82.jpg
#   inflating: test_after_train7_5/maeyupa.83.jpg
#   inflating: test_after_train7_5/maeyupa.84.jpg
#   inflating: test_after_train7_5/maeyupa.85.jpg
#   inflating: test_after_train7_5/maeyupa.86.jpg
#   inflating: test_after_train7_5/maeyupa.87.jpg
#   inflating: test_after_train7_5/maeyupa.88.jpg
#   inflating: test_after_train7_5/maeyupa.89.jpg
#   inflating: test_after_train7_5/maeyupa.9.jpg
#   inflating: test_after_train7_5/maeyupa.90.jpg
#   inflating: test_after_train7_5/maeyupa.91.jpg
#   inflating: test_after_train7_5/maeyupa.92.jpg
#   inflating: test_after_train7_5/maeyupa.93.jpg
#   inflating: test_after_train7_5/maeyupa.94.jpg
#   inflating: test_after_train7_5/maeyupa.95.jpg
#   inflating: test_after_train7_5/maeyupa.96.jpg
#   inflating: test_after_train7_5/maeyupa.97.jpg
#   inflating: test_after_train7_5/maeyupa.98.jpg
#   inflating: test_after_train7_5/maeyupa.99.jpg
#   inflating: test_after_train7_5/ocean.0.jpg
#   inflating: test_after_train7_5/ocean.1.jpg
#   inflating: test_after_train7_5/ocean.10.jpg
#   inflating: test_after_train7_5/ocean.100.jpg
#   inflating: test_after_train7_5/ocean.101.jpg
#   inflating: test_after_train7_5/ocean.102.jpg
#   inflating: test_after_train7_5/ocean.103.jpg
#   inflating: test_after_train7_5/ocean.104.jpg
#   inflating: test_after_train7_5/ocean.105.jpg
#   inflating: test_after_train7_5/ocean.106.jpg
#   inflating: test_after_train7_5/ocean.107.jpg
#   inflating: test_after_train7_5/ocean.108.jpg
#   inflating: test_after_train7_5/ocean.109.jpg
#   inflating: test_after_train7_5/ocean.11.jpg
#   inflating: test_after_train7_5/ocean.110.jpg
#   inflating: test_after_train7_5/ocean.111.jpg
#   inflating: test_after_train7_5/ocean.112.jpg
#   inflating: test_after_train7_5/ocean.113.jpg
#   inflating: test_after_train7_5/ocean.114.jpg
#   inflating: test_after_train7_5/ocean.115.jpg
#   inflating: test_after_train7_5/ocean.116.jpg
#   inflating: test_after_train7_5/ocean.117.jpg
#   inflating: test_after_train7_5/ocean.118.jpg
#   inflating: test_after_train7_5/ocean.36.jpg
#   inflating: test_after_train7_5/ocean.37.jpg
#   inflating: test_after_train7_5/ocean.38.jpg
#   inflating: test_after_train7_5/ocean.39.jpg
#   inflating: test_after_train7_5/ocean.4.jpg
#   inflating: test_after_train7_5/ocean.40.jpg
#   inflating: test_after_train7_5/ocean.41.jpg
#   inflating: test_after_train7_5/ocean.42.jpg
#   inflating: test_after_train7_5/ocean.43.jpg
#   inflating: test_after_train7_5/ocean.44.jpg
#   inflating: test_after_train7_5/ocean.45.jpg
#   inflating: test_after_train7_5/ocean.46.jpg
#   inflating: test_after_train7_5/ocean.47.jpg
#   inflating: test_after_train7_5/ocean.48.jpg
#   inflating: test_after_train7_5/ocean.49.jpg
#   inflating: test_after_train7_5/ocean.5.jpg
#   inflating: test_after_train7_5/ocean.50.jpg
#   inflating: test_after_train7_5/ocean.51.jpg
#   inflating: test_after_train7_5/ocean.52.jpg
#   inflating: test_after_train7_5/ocean.53.jpg
#   inflating: test_after_train7_5/ocean.54.jpg
#   inflating: test_after_train7_5/ocean.55.jpg
#   inflating: test_after_train7_5/ocean.56.jpg
#   inflating: test_after_train7_5/ocean.57.jpg
#   inflating: test_after_train7_5/ocean.58.jpg
#   inflating: test_after_train7_5/ocean.59.jpg
#   inflating: test_after_train7_5/ocean.6.jpg
#   inflating: test_after_train7_5/ocean.60.jpg
#   inflating: test_after_train7_5/ocean.61.jpg
#   inflating: test_after_train7_5/ocean.62.jpg
#   inflating: test_after_train7_5/ocean.63.jpg
#   inflating: test_after_train7_5/ocean.64.jpg
#   inflating: test_after_train7_5/ocean.65.jpg
#   inflating: test_after_train7_5/ocean.66.jpg
#   inflating: test_after_train7_5/ocean.67.jpg
#   inflating: test_after_train7_5/ocean.68.jpg
#   inflating: test_after_train7_5/ocean.69.jpg
#   inflating: test_after_train7_5/ocean.7.jpg
#   inflating: test_after_train7_5/ocean.70.jpg
#   inflating: test_after_train7_5/ocean.71.jpg
#   inflating: test_after_train7_5/ocean.72.jpg
#   inflating: test_after_train7_5/ocean.73.jpg
#   inflating: test_after_train7_5/ocean.74.jpg
#   inflating: test_after_train7_5/ocean.75.jpg
#   inflating: test_after_train7_5/ocean.76.jpg
#   inflating: test_after_train7_5/ocean.77.jpg
#   inflating: test_after_train7_5/ocean.78.jpg
#   inflating: test_after_train7_5/ocean.79.jpg
#   inflating: test_after_train7_5/ocean.8.jpg
#   inflating: test_after_train7_5/ocean.80.jpg
#   inflating: test_after_train7_5/ocean.81.jpg
#   inflating: test_after_train7_5/ocean.82.jpg
#   inflating: test_after_train7_5/ocean.83.jpg
#   inflating: test_after_train7_5/ocean.84.jpg
#   inflating: test_after_train7_5/ocean.85.jpg
#   inflating: test_after_train7_5/ocean.86.jpg
#   inflating: test_after_train7_5/ocean.87.jpg
#   inflating: test_after_train7_5/ocean.88.jpg
#   inflating: test_after_train7_5/ocean.89.jpg
#   inflating: test_after_train7_5/ocean.9.jpg
#   inflating: test_after_train7_5/ocean.90.jpg
#   inflating: test_after_train7_5/ocean.91.jpg
#   inflating: test_after_train7_5/ocean.92.jpg
#   inflating: test_after_train7_5/ocean.93.jpg
#   inflating: test_after_train7_5/ocean.94.jpg
#   inflating: test_after_train7_5/ocean.95.jpg
#   inflating: test_after_train7_5/ocean.96.jpg
#   inflating: test_after_train7_5/ocean.97.jpg
#   inflating: test_after_train7_5/ocean.98.jpg
#   inflating: test_after_train7_5/ocean.99.jpg
#   inflating: test_after_train7_5/zapnuer.0.jpg
#   inflating: test_after_train7_5/zapnuer.1.jpg
#   inflating: test_after_train7_5/zapnuer.10.jpg
#   inflating: test_after_train7_5/zapnuer.100.jpg
#   inflating: test_after_train7_5/zapnuer.101.jpg
#   inflating: test_after_train7_5/zapnuer.102.jpg
#   inflating: test_after_train7_5/zapnuer.103.jpg
#   inflating: test_after_train7_5/zapnuer.104.jpg
#   inflating: test_after_train7_5/zapnuer.105.jpg
#   inflating: test_after_train7_5/zapnuer.106.jpg
#   inflating: test_after_train7_5/zapnuer.107.jpg
#   inflating: test_after_train7_5/zapnuer.108.jpg
#   inflating: test_after_train7_5/zapnuer.109.jpg
#   inflating: test_after_train7_5/zapnuer.11.jpg
#   inflating: test_after_train7_5/zapnuer.110.jpg
#   inflating: test_after_train7_5/zapnuer.111.jpg
#   inflating: test_after_train7_5/zapnuer.112.jpg
#   inflating: test_after_train7_5/zapnuer.113.jpg
#   inflating: test_after_train7_5/zapnuer.114.jpg
#   inflating: test_after_train7_5/zapnuer.115.jpg
#   inflating: test_after_train7_5/zapnuer.116.jpg
#   inflating: test_after_train7_5/zapnuer.117.jpg
#   inflating: test_after_train7_5/zapnuer.118.jpg
#   inflating: test_after_train7_5/zapnuer.119.jpg
#   inflating: test_after_train7_5/zapnuer.12.jpg
#   inflating: test_after_train7_5/zapnuer.120.jpg
#   inflating: test_after_train7_5/zapnuer.121.jpg
#   inflating: test_after_train7_5/zapnuer.122.jpg
#   inflating: test_after_train7_5/zapnuer.123.jpg
#   inflating: test_after_train7_5/zapnuer.124.jpg
#   inflating: test_after_train7_5/zapnuer.125.jpg
#   inflating: test_after_train7_5/zapnuer.126.jpg
#   inflating: test_after_train7_5/zapnuer.127.jpg
#   inflating: test_after_train7_5/zapnuer.128.jpg
#   inflating: test_after_train7_5/zapnuer.129.jpg
#   inflating: test_after_train7_5/zapnuer.13.jpg
#   inflating: test_after_train7_5/zapnuer.130.jpg
#   inflating: test_after_train7_5/zapnuer.131.jpg
#   inflating: test_after_train7_5/zapnuer.132.jpg
#   inflating: test_after_train7_5/zapnuer.133.jpg
#   inflating: test_after_train7_5/zapnuer.134.jpg
#   inflating: test_after_train7_5/zapnuer.135.jpg
#   inflating: test_after_train7_5/zapnuer.136.jpg
#   inflating: test_after_train7_5/zapnuer.137.jpg
#   inflating: test_after_train7_5/zapnuer.138.jpg
#   inflating: test_after_train7_5/zapnuer.139.jpg
#   inflating: test_after_train7_5/zapnuer.14.jpg
#   inflating: test_after_train7_5/zapnuer.140.jpg
#   inflating: test_after_train7_5/zapnuer.141.jpg
#   inflating: test_after_train7_5/zapnuer.142.jpg
#   inflating: test_after_train7_5/zapnuer.143.jpg
#   inflating: test_after_train7_5/zapnuer.144.jpg
#   inflating: test_after_train7_5/zapnuer.145.jpg
#   inflating: test_after_train7_5/zapnuer.146.jpg
#   inflating: test_after_train7_5/zapnuer.147.jpg
#   inflating: test_after_train7_5/zapnuer.148.jpg
#   inflating: test_after_train7_5/zapnuer.149.jpg
#   inflating: test_after_train7_5/zapnuer.15.jpg
#   inflating: test_after_train7_5/zapnuer.150.jpg
#   inflating: test_after_train7_5/zapnuer.151.jpg
#   inflating: test_after_train7_5/zapnuer.152.jpg
#   inflating: test_after_train7_5/zapnuer.153.jpg
#   inflating: test_after_train7_5/zapnuer.154.jpg
#   inflating: test_after_train7_5/zapnuer.155.jpg
#   inflating: test_after_train7_5/zapnuer.156.jpg
#   inflating: test_after_train7_5/zapnuer.157.jpg
#   inflating: test_after_train7_5/zapnuer.158.jpg
#   inflating: test_after_train7_5/zapnuer.159.jpg
#   inflating: test_after_train7_5/zapnuer.16.jpg
#   inflating: test_after_train7_5/zapnuer.160.jpg
#   inflating: test_after_train7_5/zapnuer.161.jpg
#   inflating: test_after_train7_5/zapnuer.162.jpg
#   inflating: test_after_train7_5/zapnuer.163.jpg
#   inflating: test_after_train7_5/zapnuer.164.jpg
#   inflating: test_after_train7_5/zapnuer.165.jpg
#   inflating: test_after_train7_5/zapnuer.166.jpg
#   inflating: test_after_train7_5/zapnuer.167.jpg
#   inflating: test_after_train7_5/zapnuer.168.jpg
#   inflating: test_after_train7_5/zapnuer.169.jpg
#   inflating: test_after_train7_5/zapnuer.17.jpg
#   inflating: test_after_train7_5/zapnuer.170.jpg
#   inflating: test_after_train7_5/zapnuer.171.jpg
#   inflating: test_after_train7_5/zapnuer.172.jpg
#   inflating: test_after_train7_5/zapnuer.173.jpg
#   inflating: test_after_train7_5/zapnuer.174.jpg
#   inflating: test_after_train7_5/zapnuer.175.jpg
#   inflating: test_after_train7_5/zapnuer.176.jpg
#   inflating: test_after_train7_5/zapnuer.177.jpg
#   inflating: test_after_train7_5/zapnuer.178.jpg
#   inflating: test_after_train7_5/zapnuer.179.jpg
#   inflating: test_after_train7_5/zapnuer.18.jpg
#   inflating: test_after_train7_5/zapnuer.180.jpg
#   inflating: test_after_train7_5/zapnuer.181.jpg
#   inflating: test_after_train7_5/zapnuer.182.jpg
#   inflating: test_after_train7_5/zapnuer.183.jpg
#   inflating: test_after_train7_5/zapnuer.184.jpg
#   inflating: test_after_train7_5/zapnuer.185.jpg
#   inflating: test_after_train7_5/zapnuer.186.jpg
#   inflating: test_after_train7_5/zapnuer.187.jpg
#   inflating: test_after_train7_5/zapnuer.188.jpg
#   inflating: test_after_train7_5/zapnuer.189.jpg
#   inflating: test_after_train7_5/zapnuer.19.jpg
#   inflating: test_after_train7_5/zapnuer.190.jpg
#   inflating: test_after_train7_5/zapnuer.191.jpg
#   inflating: test_after_train7_5/zapnuer.192.jpg
#   inflating: test_after_train7_5/zapnuer.193.jpg
#   inflating: test_after_train7_5/zapnuer.194.jpg
#   inflating: test_after_train7_5/zapnuer.195.jpg
#   inflating: test_after_train7_5/zapnuer.196.jpg
#   inflating: test_after_train7_5/zapnuer.197.jpg
#   inflating: test_after_train7_5/zapnuer.198.jpg
#   inflating: test_after_train7_5/zapnuer.199.jpg
#   inflating: test_after_train7_5/zapnuer.2.jpg
#   inflating: test_after_train7_5/zapnuer.20.jpg
#   inflating: test_after_train7_5/zapnuer.200.jpg
#   inflating: test_after_train7_5/zapnuer.201.jpg
#   inflating: test_after_train7_5/zapnuer.202.jpg
#   inflating: test_after_train7_5/zapnuer.203.jpg
#   inflating: test_after_train7_5/zapnuer.204.jpg
#   inflating: test_after_train7_5/zapnuer.205.jpg
#   inflating: test_after_train7_5/zapnuer.206.jpg
#   inflating: test_after_train7_5/zapnuer.207.jpg
#   inflating: test_after_train7_5/zapnuer.208.jpg
#   inflating: test_after_train7_5/zapnuer.209.jpg
#   inflating: test_after_train7_5/zapnuer.21.jpg
#   inflating: test_after_train7_5/zapnuer.210.jpg
#   inflating: test_after_train7_5/zapnuer.211.jpg
#   inflating: test_after_train7_5/zapnuer.212.jpg
#   inflating: test_after_train7_5/zapnuer.213.jpg
#   inflating: test_after_train7_5/zapnuer.214.jpg
#   inflating: test_after_train7_5/zapnuer.215.jpg
#   inflating: test_after_train7_5/zapnuer.216.jpg
#   inflating: test_after_train7_5/zapnuer.217.jpg
#   inflating: test_after_train7_5/zapnuer.218.jpg
#   inflating: test_after_train7_5/zapnuer.219.jpg
#   inflating: test_after_train7_5/zapnuer.22.jpg
#   inflating: test_after_train7_5/zapnuer.220.jpg
#   inflating: test_after_train7_5/zapnuer.221.jpg
#   inflating: test_after_train7_5/zapnuer.222.jpg
#   inflating: test_after_train7_5/zapnuer.223.jpg
#   inflating: test_after_train7_5/zapnuer.224.jpg
#   inflating: test_after_train7_5/zapnuer.225.jpg
#   inflating: test_after_train7_5/zapnuer.226.jpg
#   inflating: test_after_train7_5/zapnuer.227.jpg
#   inflating: test_after_train7_5/zapnuer.228.jpg
#   inflating: test_after_train7_5/zapnuer.229.jpg
#   inflating: test_after_train7_5/zapnuer.23.jpg
#   inflating: test_after_train7_5/zapnuer.230.jpg
#   inflating: test_after_train7_5/zapnuer.231.jpg
#   inflating: test_after_train7_5/zapnuer.232.jpg
#   inflating: test_after_train7_5/zapnuer.233.jpg
#   inflating: test_after_train7_5/zapnuer.234.jpg
#   inflating: test_after_train7_5/zapnuer.235.jpg
#   inflating: test_after_train7_5/zapnuer.236.jpg
#   inflating: test_after_train7_5/zapnuer.237.jpg
#   inflating: test_after_train7_5/zapnuer.238.jpg
#   inflating: test_after_train7_5/zapnuer.239.jpg
#   inflating: test_after_train7_5/zapnuer.24.jpg
#   inflating: test_after_train7_5/zapnuer.240.jpg
#   inflating: test_after_train7_5/zapnuer.241.jpg
#   inflating: test_after_train7_5/zapnuer.242.jpg
#   inflating: test_after_train7_5/zapnuer.243.jpg
#   inflating: test_after_train7_5/zapnuer.244.jpg
#   inflating: test_after_train7_5/zapnuer.245.jpg
#   inflating: test_after_train7_5/zapnuer.246.jpg
#   inflating: test_after_train7_5/zapnuer.247.jpg
#   inflating: test_after_train7_5/zapnuer.248.jpg
#   inflating: test_after_train7_5/zapnuer.249.jpg
#   inflating: test_after_train7_5/zapnuer.25.jpg
#   inflating: test_after_train7_5/zapnuer.250.jpg
#   inflating: test_after_train7_5/zapnuer.251.jpg
#   inflating: test_after_train7_5/zapnuer.252.jpg
#   inflating: test_after_train7_5/zapnuer.253.jpg
#   inflating: test_after_train7_5/zapnuer.254.jpg
#   inflating: test_after_train7_5/zapnuer.255.jpg
#   inflating: test_after_train7_5/zapnuer.256.jpg
#   inflating: test_after_train7_5/zapnuer.257.jpg
#   inflating: test_after_train7_5/zapnuer.258.jpg
#   inflating: test_after_train7_5/zapnuer.259.jpg
#   inflating: test_after_train7_5/zapnuer.26.jpg
#   inflating: test_after_train7_5/zapnuer.260.jpg
#   inflating: test_after_train7_5/zapnuer.261.jpg
#   inflating: test_after_train7_5/zapnuer.262.jpg
#   inflating: test_after_train7_5/zapnuer.263.jpg
#   inflating: test_after_train7_5/zapnuer.264.jpg
#   inflating: test_after_train7_5/zapnuer.265.jpg
#   inflating: test_after_train7_5/zapnuer.266.jpg
#   inflating: test_after_train7_5/zapnuer.267.jpg
#   inflating: test_after_train7_5/zapnuer.268.jpg
#   inflating: test_after_train7_5/zapnuer.269.jpg
#   inflating: test_after_train7_5/zapnuer.27.jpg
#   inflating: test_after_train7_5/zapnuer.270.jpg
#   inflating: test_after_train7_5/zapnuer.271.jpg
#   inflating: test_after_train7_5/zapnuer.272.jpg
#   inflating: test_after_train7_5/zapnuer.273.jpg
#   inflating: test_after_train7_5/zapnuer.274.jpg
#   inflating: test_after_train7_5/zapnuer.275.jpg
#   inflating: test_after_train7_5/zapnuer.28.jpg
#   inflating: test_after_train7_5/zapnuer.29.jpg
#   inflating: test_after_train7_5/zapnuer.3.jpg
#   inflating: test_after_train7_5/zapnuer.30.jpg
#   inflating: test_after_train7_5/zapnuer.31.jpg
#   inflating: test_after_train7_5/zapnuer.32.jpg
#   inflating: test_after_train7_5/zapnuer.33.jpg
#   inflating: test_after_train7_5/zapnuer.34.jpg
#   inflating: test_after_train7_5/zapnuer.35.jpg
#   inflating: test_after_train7_5/zapnuer.36.jpg
#   inflating: test_after_train7_5/zapnuer.37.jpg
#   inflating: test_after_train7_5/zapnuer.38.jpg
#   inflating: test_after_train7_5/zapnuer.39.jpg
#   inflating: test_after_train7_5/zapnuer.4.jpg
#   inflating: test_after_train7_5/zapnuer.40.jpg
#   inflating: test_after_train7_5/zapnuer.41.jpg
#   inflating: test_after_train7_5/zapnuer.42.jpg
#   inflating: test_after_train7_5/zapnuer.43.jpg
#   inflating: test_after_train7_5/zapnuer.44.jpg
#   inflating: test_after_train7_5/zapnuer.45.jpg
#   inflating: test_after_train7_5/zapnuer.46.jpg
#   inflating: test_after_train7_5/zapnuer.47.jpg
#   inflating: test_after_train7_5/zapnuer.48.jpg
#   inflating: test_after_train7_5/zapnuer.49.jpg
#   inflating: test_after_train7_5/zapnuer.5.jpg
#   inflating: test_after_train7_5/zapnuer.50.jpg
#   inflating: test_after_train7_5/zapnuer.51.jpg
#   inflating: test_after_train7_5/zapnuer.52.jpg
#   inflating: test_after_train7_5/zapnuer.53.jpg
#   inflating: test_after_train7_5/zapnuer.54.jpg
#   inflating: test_after_train7_5/zapnuer.55.jpg
#   inflating: test_after_train7_5/zapnuer.56.jpg
#   inflating: test_after_train7_5/zapnuer.57.jpg
#   inflating: test_after_train7_5/zapnuer.58.jpg
#   inflating: test_after_train7_5/zapnuer.59.jpg
#   inflating: test_after_train7_5/zapnuer.6.jpg
#   inflating: test_after_train7_5/zapnuer.60.jpg
#   inflating: test_after_train7_5/zapnuer.61.jpg
#   inflating: test_after_train7_5/zapnuer.62.jpg
#   inflating: test_after_train7_5/zapnuer.63.jpg
#   inflating: test_after_train7_5/zapnuer.64.jpg
#   inflating: test_after_train7_5/zapnuer.65.jpg
#   inflating: test_after_train7_5/zapnuer.66.jpg
#   inflating: test_after_train7_5/zapnuer.67.jpg
#   inflating: test_after_train7_5/zapnuer.68.jpg
#   inflating: test_after_train7_5/zapnuer.69.jpg
#   inflating: test_after_train7_5/zapnuer.7.jpg
#   inflating: test_after_train7_5/zapnuer.70.jpg
#   inflating: test_after_train7_5/zapnuer.71.jpg
#   inflating: test_after_train7_5/zapnuer.72.jpg
#   inflating: test_after_train7_5/zapnuer.73.jpg
#   inflating: test_after_train7_5/zapnuer.74.jpg
#   inflating: test_after_train7_5/zapnuer.75.jpg
#   inflating: test_after_train7_5/zapnuer.76.jpg
#   inflating: test_after_train7_5/zapnuer.77.jpg
#   inflating: test_after_train7_5/zapnuer.78.jpg
#   inflating: test_after_train7_5/zapnuer.79.jpg
#   inflating: test_after_train7_5/zapnuer.8.jpg
#   inflating: test_after_train7_5/zapnuer.80.jpg
#   inflating: test_after_train7_5/zapnuer.81.jpg
#   inflating: test_after_train7_5/zapnuer.82.jpg
#   inflating: test_after_train7_5/zapnuer.83.jpg
#   inflating: test_after_train7_5/zapnuer.84.jpg
#   inflating: test_after_train7_5/zapnuer.85.jpg
#   inflating: test_after_train7_5/zapnuer.86.jpg
#   inflating: test_after_train7_5/zapnuer.87.jpg
#   inflating: test_after_train7_5/zapnuer.88.jpg
#   inflating: test_after_train7_5/zapnuer.89.jpg
#   inflating: test_after_train7_5/zapnuer.9.jpg
#   inflating: test_after_train7_5/zapnuer.90.jpg
#   inflating: test_after_train7_5/zapnuer.91.jpg
#   inflating: test_after_train7_5/zapnuer.92.jpg
#   inflating: test_after_train7_5/zapnuer.93.jpg
#   inflating: test_after_train7_5/zapnuer.94.jpg
#   inflating: test_after_train7_5/zapnuer.95.jpg
#   inflating: test_after_train7_5/zapnuer.96.jpg
#   inflating: test_after_train7_5/zapnuer.97.jpg
#   inflating: test_after_train7_5/zapnuer.98.jpg
#   inflating: test_after_train7_5/zapnuer.99.jpg
#   inflating: test_after_train7_5/zapnuerchick.0.jpg
#   inflating: test_after_train7_5/zapnuerchick.1.jpg
#   inflating: test_after_train7_5/zapnuerchick.10.jpg
#   inflating: test_after_train7_5/zapnuerchick.100.jpg
#   inflating: test_after_train7_5/zapnuerchick.101.jpg
#   inflating: test_after_train7_5/zapnuerchick.102.jpg
#   inflating: test_after_train7_5/zapnuerchick.103.jpg
#   inflating: test_after_train7_5/zapnuerchick.104.jpg
#   inflating: test_after_train7_5/zapnuerchick.105.jpg
#   inflating: test_after_train7_5/zapnuerchick.106.jpg
#   inflating: test_after_train7_5/zapnuerchick.107.jpg
#   inflating: test_after_train7_5/zapnuerchick.108.jpg
#   inflating: test_after_train7_5/zapnuerchick.109.jpg
#   inflating: test_after_train7_5/zapnuerchick.11.jpg
#   inflating: test_after_train7_5/zapnuerchick.110.jpg
#   inflating: test_after_train7_5/zapnuerchick.111.jpg
#   inflating: test_after_train7_5/zapnuerchick.112.jpg
#   inflating: test_after_train7_5/zapnuerchick.113.jpg
#   inflating: test_after_train7_5/zapnuerchick.114.jpg
#   inflating: test_after_train7_5/zapnuerchick.115.jpg
#   inflating: test_after_train7_5/zapnuerchick.116.jpg
#   inflating: test_after_train7_5/zapnuerchick.117.jpg
#   inflating: test_after_train7_5/zapnuerchick.118.jpg
#   inflating: test_after_train7_5/zapnuerchick.119.jpg
#   inflating: test_after_train7_5/zapnuerchick.12.jpg
#   inflating: test_after_train7_5/zapnuerchick.120.jpg
#   inflating: test_after_train7_5/zapnuerchick.121.jpg
#   inflating: test_after_train7_5/zapnuerchick.122.jpg
#   inflating: test_after_train7_5/zapnuerchick.123.jpg
#   inflating: test_after_train7_5/zapnuerchick.124.jpg
#   inflating: test_after_train7_5/zapnuerchick.125.jpg
#   inflating: test_after_train7_5/zapnuerchick.126.jpg
#   inflating: test_after_train7_5/zapnuerchick.127.jpg
#   inflating: test_after_train7_5/zapnuerchick.128.jpg
#   inflating: test_after_train7_5/zapnuerchick.129.jpg
#   inflating: test_after_train7_5/zapnuerchick.13.jpg
#   inflating: test_after_train7_5/zapnuerchick.130.jpg
#   inflating: test_after_train7_5/zapnuerchick.131.jpg
#   inflating: test_after_train7_5/zapnuerchick.132.jpg
#   inflating: test_after_train7_5/zapnuerchick.133.jpg
#   inflating: test_after_train7_5/zapnuerchick.134.jpg
#   inflating: test_after_train7_5/zapnuerchick.135.jpg
#   inflating: test_after_train7_5/zapnuerchick.136.jpg
#   inflating: test_after_train7_5/zapnuerchick.137.jpg
#   inflating: test_after_train7_5/zapnuerchick.138.jpg
#   inflating: test_after_train7_5/zapnuerchick.139.jpg
#   inflating: test_after_train7_5/zapnuerchick.14.jpg
#   inflating: test_after_train7_5/zapnuerchick.140.jpg
#   inflating: test_after_train7_5/zapnuerchick.141.jpg
#   inflating: test_after_train7_5/zapnuerchick.142.jpg
#   inflating: test_after_train7_5/zapnuerchick.143.jpg
#   inflating: test_after_train7_5/zapnuerchick.144.jpg
#   inflating: test_after_train7_5/zapnuerchick.145.jpg
#   inflating: test_after_train7_5/zapnuerchick.146.jpg
#   inflating: test_after_train7_5/zapnuerchick.147.jpg
#   inflating: test_after_train7_5/zapnuerchick.148.jpg
#   inflating: test_after_train7_5/zapnuerchick.149.jpg
#   inflating: test_after_train7_5/zapnuerchick.15.jpg
#   inflating: test_after_train7_5/zapnuerchick.150.jpg
#   inflating: test_after_train7_5/zapnuerchick.151.jpg
#   inflating: test_after_train7_5/zapnuerchick.152.jpg
#   inflating: test_after_train7_5/zapnuerchick.153.jpg
#   inflating: test_after_train7_5/zapnuerchick.154.jpg
#   inflating: test_after_train7_5/zapnuerchick.155.jpg
#   inflating: test_after_train7_5/zapnuerchick.156.jpg
#   inflating: test_after_train7_5/zapnuerchick.157.jpg
#   inflating: test_after_train7_5/zapnuerchick.158.jpg
#   inflating: test_after_train7_5/zapnuerchick.159.jpg
#   inflating: test_after_train7_5/zapnuerchick.16.jpg
#   inflating: test_after_train7_5/zapnuerchick.160.jpg
#   inflating: test_after_train7_5/zapnuerchick.161.jpg
#   inflating: test_after_train7_5/zapnuerchick.162.jpg
#   inflating: test_after_train7_5/zapnuerchick.163.jpg
#   inflating: test_after_train7_5/zapnuerchick.164.jpg
#   inflating: test_after_train7_5/zapnuerchick.165.jpg
#   inflating: test_after_train7_5/zapnuerchick.166.jpg
#   inflating: test_after_train7_5/zapnuerchick.167.jpg
#   inflating: test_after_train7_5/zapnuerchick.168.jpg
#   inflating: test_after_train7_5/zapnuerchick.169.jpg
#   inflating: test_after_train7_5/zapnuerchick.17.jpg
#   inflating: test_after_train7_5/zapnuerchick.170.jpg
#   inflating: test_after_train7_5/zapnuerchick.171.jpg
#   inflating: test_after_train7_5/zapnuerchick.172.jpg
#   inflating: test_after_train7_5/zapnuerchick.173.jpg
#   inflating: test_after_train7_5/zapnuerchick.174.jpg
#   inflating: test_after_train7_5/zapnuerchick.175.jpg
#   inflating: test_after_train7_5/zapnuerchick.176.jpg
#   inflating: test_after_train7_5/zapnuerchick.177.jpg
#   inflating: test_after_train7_5/zapnuerchick.178.jpg
#   inflating: test_after_train7_5/zapnuerchick.179.jpg
#   inflating: test_after_train7_5/zapnuerchick.18.jpg
#   inflating: test_after_train7_5/zapnuerchick.180.jpg
#   inflating: test_after_train7_5/zapnuerchick.181.jpg
#   inflating: test_after_train7_5/zapnuerchick.182.jpg
#   inflating: test_after_train7_5/zapnuerchick.183.jpg
#   inflating: test_after_train7_5/zapnuerchick.184.jpg
#   inflating: test_after_train7_5/zapnuerchick.185.jpg
#   inflating: test_after_train7_5/zapnuerchick.186.jpg
#   inflating: test_after_train7_5/zapnuerchick.187.jpg
#   inflating: test_after_train7_5/zapnuerchick.188.jpg
#   inflating: test_after_train7_5/zapnuerchick.189.jpg
#   inflating: test_after_train7_5/zapnuerchick.19.jpg
#   inflating: test_after_train7_5/zapnuerchick.190.jpg
#   inflating: test_after_train7_5/zapnuerchick.191.jpg
#   inflating: test_after_train7_5/zapnuerchick.192.jpg
#   inflating: test_after_train7_5/zapnuerchick.193.jpg
#   inflating: test_after_train7_5/zapnuerchick.194.jpg
#   inflating: test_after_train7_5/zapnuerchick.195.jpg
#   inflating: test_after_train7_5/zapnuerchick.196.jpg
#   inflating: test_after_train7_5/zapnuerchick.197.jpg
#   inflating: test_after_train7_5/zapnuerchick.198.jpg
#   inflating: test_after_train7_5/zapnuerchick.199.jpg
#   inflating: test_after_train7_5/zapnuerchick.2.jpg
#   inflating: test_after_train7_5/zapnuerchick.20.jpg
#   inflating: test_after_train7_5/zapnuerchick.200.jpg
#   inflating: test_after_train7_5/zapnuerchick.201.jpg
#   inflating: test_after_train7_5/zapnuerchick.202.jpg
#   inflating: test_after_train7_5/zapnuerchick.203.jpg
#   inflating: test_after_train7_5/zapnuerchick.204.jpg
#   inflating: test_after_train7_5/zapnuerchick.205.jpg
#   inflating: test_after_train7_5/zapnuerchick.206.jpg
#   inflating: test_after_train7_5/zapnuerchick.207.jpg
#   inflating: test_after_train7_5/zapnuerchick.208.jpg
#   inflating: test_after_train7_5/zapnuerchick.209.jpg
#   inflating: test_after_train7_5/zapnuerchick.21.jpg
#   inflating: test_after_train7_5/zapnuerchick.210.jpg
#   inflating: test_after_train7_5/zapnuerchick.211.jpg
#   inflating: test_after_train7_5/zapnuerchick.212.jpg
#   inflating: test_after_train7_5/zapnuerchick.213.jpg
#   inflating: test_after_train7_5/zapnuerchick.214.jpg
#   inflating: test_after_train7_5/zapnuerchick.215.jpg
#   inflating: test_after_train7_5/zapnuerchick.216.jpg
#   inflating: test_after_train7_5/zapnuerchick.217.jpg
#   inflating: test_after_train7_5/zapnuerchick.218.jpg
#   inflating: test_after_train7_5/zapnuerchick.219.jpg
#   inflating: test_after_train7_5/zapnuerchick.22.jpg
#   inflating: test_after_train7_5/zapnuerchick.220.jpg
#   inflating: test_after_train7_5/zapnuerchick.221.jpg
#   inflating: test_after_train7_5/zapnuerchick.222.jpg
#   inflating: test_after_train7_5/zapnuerchick.223.jpg
#   inflating: test_after_train7_5/zapnuerchick.224.jpg
#   inflating: test_after_train7_5/zapnuerchick.225.jpg
#   inflating: test_after_train7_5/zapnuerchick.226.jpg
#   inflating: test_after_train7_5/zapnuerchick.227.jpg
#   inflating: test_after_train7_5/zapnuerchick.228.jpg
#   inflating: test_after_train7_5/zapnuerchick.229.jpg
#   inflating: test_after_train7_5/zapnuerchick.23.jpg
#   inflating: test_after_train7_5/zapnuerchick.230.jpg
#   inflating: test_after_train7_5/zapnuerchick.231.jpg
#   inflating: test_after_train7_5/zapnuerchick.232.jpg
#   inflating: test_after_train7_5/zapnuerchick.233.jpg
#   inflating: test_after_train7_5/zapnuerchick.234.jpg
#   inflating: test_after_train7_5/zapnuerchick.235.jpg
#   inflating: test_after_train7_5/zapnuerchick.236.jpg
#   inflating: test_after_train7_5/zapnuerchick.237.jpg
#   inflating: test_after_train7_5/zapnuerchick.238.jpg
#   inflating: test_after_train7_5/zapnuerchick.239.jpg
#   inflating: test_after_train7_5/zapnuerchick.24.jpg
#   inflating: test_after_train7_5/zapnuerchick.240.jpg
#   inflating: test_after_train7_5/zapnuerchick.241.jpg
#   inflating: test_after_train7_5/zapnuerchick.242.jpg
#   inflating: test_after_train7_5/zapnuerchick.243.jpg
#   inflating: test_after_train7_5/zapnuerchick.244.jpg
#   inflating: test_after_train7_5/zapnuerchick.245.jpg
#   inflating: test_after_train7_5/zapnuerchick.246.jpg
#   inflating: test_after_train7_5/zapnuerchick.247.jpg
#   inflating: test_after_train7_5/zapnuerchick.248.jpg
#   inflating: test_after_train7_5/zapnuerchick.249.jpg
#   inflating: test_after_train7_5/zapnuerchick.25.jpg
#   inflating: test_after_train7_5/zapnuerchick.250.jpg
#   inflating: test_after_train7_5/zapnuerchick.251.jpg
#   inflating: test_after_train7_5/zapnuerchick.252.jpg
#   inflating: test_after_train7_5/zapnuerchick.253.jpg
#   inflating: test_after_train7_5/zapnuerchick.254.jpg
#   inflating: test_after_train7_5/zapnuerchick.255.jpg
#   inflating: test_after_train7_5/zapnuerchick.256.jpg
#   inflating: test_after_train7_5/zapnuerchick.257.jpg
#   inflating: test_after_train7_5/zapnuerchick.258.jpg
#   inflating: test_after_train7_5/zapnuerchick.259.jpg
#   inflating: test_after_train7_5/zapnuerchick.26.jpg
#   inflating: test_after_train7_5/zapnuerchick.260.jpg
#   inflating: test_after_train7_5/zapnuerchick.261.jpg
#   inflating: test_after_train7_5/zapnuerchick.262.jpg
#   inflating: test_after_train7_5/zapnuerchick.263.jpg
#   inflating: test_after_train7_5/zapnuerchick.264.jpg
#   inflating: test_after_train7_5/zapnuerchick.265.jpg
#   inflating: test_after_train7_5/zapnuerchick.266.jpg
#   inflating: test_after_train7_5/zapnuerchick.267.jpg
#   inflating: test_after_train7_5/zapnuerchick.268.jpg
#   inflating: test_after_train7_5/zapnuerchick.269.jpg
#   inflating: test_after_train7_5/zapnuerchick.27.jpg
#   inflating: test_after_train7_5/zapnuerchick.270.jpg
#   inflating: test_after_train7_5/zapnuerchick.271.jpg
#   inflating: test_after_train7_5/zapnuerchick.272.jpg
#   inflating: test_after_train7_5/zapnuerchick.273.jpg
#   inflating: test_after_train7_5/zapnuerchick.274.jpg
#   inflating: test_after_train7_5/zapnuerchick.275.jpg
#   inflating: test_after_train7_5/zapnuerchick.276.jpg
#   inflating: test_after_train7_5/zapnuerchick.277.jpg
#   inflating: test_after_train7_5/zapnuerchick.28.jpg
#   inflating: test_after_train7_5/zapnuerchick.29.jpg
#   inflating: test_after_train7_5/zapnuerchick.3.jpg
#   inflating: test_after_train7_5/zapnuerchick.30.jpg
#   inflating: test_after_train7_5/zapnuerchick.31.jpg
#   inflating: test_after_train7_5/zapnuerchick.32.jpg
#   inflating: test_after_train7_5/zapnuerchick.33.jpg
#   inflating: test_after_train7_5/zapnuerchick.34.jpg
#   inflating: test_after_train7_5/zapnuerchick.35.jpg
#   inflating: test_after_train7_5/zapnuerchick.36.jpg
#   inflating: test_after_train7_5/zapnuerchick.37.jpg
#   inflating: test_after_train7_5/zapnuerchick.38.jpg
#   inflating: test_after_train7_5/zapnuerchick.39.jpg
#   inflating: test_after_train7_5/zapnuerchick.4.jpg
#   inflating: test_after_train7_5/zapnuerchick.40.jpg
#   inflating: test_after_train7_5/zapnuerchick.41.jpg
#   inflating: test_after_train7_5/zapnuerchick.42.jpg
#   inflating: test_after_train7_5/zapnuerchick.43.jpg
#   inflating: test_after_train7_5/zapnuerchick.44.jpg
#   inflating: test_after_train7_5/zapnuerchick.45.jpg
#   inflating: test_after_train7_5/zapnuerchick.46.jpg
#   inflating: test_after_train7_5/zapnuerchick.47.jpg
#   inflating: test_after_train7_5/zapnuerchick.48.jpg
#   inflating: test_after_train7_5/zapnuerchick.49.jpg
#   inflating: test_after_train7_5/zapnuerchick.5.jpg
#   inflating: test_after_train7_5/zapnuerchick.50.jpg
#   inflating: test_after_train7_5/zapnuerchick.51.jpg
#   inflating: test_after_train7_5/zapnuerchick.52.jpg
#   inflating: test_after_train7_5/zapnuerchick.53.jpg
#   inflating: test_after_train7_5/zapnuerchick.54.jpg
#   inflating: test_after_train7_5/zapnuerchick.55.jpg
#   inflating: test_after_train7_5/zapnuerchick.56.jpg
#   inflating: test_after_train7_5/zapnuerchick.57.jpg
#   inflating: test_after_train7_5/zapnuerchick.58.jpg
#   inflating: test_after_train7_5/zapnuerchick.59.jpg
#   inflating: test_after_train7_5/zapnuerchick.6.jpg
#   inflating: test_after_train7_5/zapnuerchick.60.jpg
#   inflating: test_after_train7_5/zapnuerchick.61.jpg
#   inflating: test_after_train7_5/zapnuerchick.62.jpg
#   inflating: test_after_train7_5/zapnuerchick.63.jpg
#   inflating: test_after_train7_5/zapnuerchick.64.jpg
#   inflating: test_after_train7_5/zapnuerchick.65.jpg
#   inflating: test_after_train7_5/zapnuerchick.66.jpg
#   inflating: test_after_train7_5/zapnuerchick.67.jpg
#   inflating: test_after_train7_5/zapnuerchick.68.jpg
#   inflating: test_after_train7_5/zapnuerchick.69.jpg
#   inflating: test_after_train7_5/zapnuerchick.7.jpg
#   inflating: test_after_train7_5/zapnuerchick.70.jpg
#   inflating: test_after_train7_5/zapnuerchick.71.jpg
#   inflating: test_after_train7_5/zapnuerchick.72.jpg
#   inflating: test_after_train7_5/zapnuerchick.73.jpg
#   inflating: test_after_train7_5/zapnuerchick.74.jpg
#   inflating: test_after_train7_5/zapnuerchick.75.jpg
#   inflating: test_after_train7_5/zapnuerchick.76.jpg
#   inflating: test_after_train7_5/zapnuerchick.77.jpg
#   inflating: test_after_train7_5/zapnuerchick.78.jpg
#   inflating: test_after_train7_5/zapnuerchick.79.jpg
#   inflating: test_after_train7_5/zapnuerchick.8.jpg
#   inflating: test_after_train7_5/zapnuerchick.80.jpg
#   inflating: test_after_train7_5/zapnuerchick.81.jpg
#   inflating: test_after_train7_5/zapnuerchick.82.jpg
#   inflating: test_after_train7_5/zapnuerchick.83.jpg
#   inflating: test_after_train7_5/zapnuerchick.84.jpg
#   inflating: test_after_train7_5/zapnuerchick.85.jpg
#   inflating: test_after_train7_5/zapnuerchick.86.jpg
#   inflating: test_after_train7_5/zapnuerchick.87.jpg
#   inflating: test_after_train7_5/zapnuerchick.88.jpg
#   inflating: test_after_train7_5/zapnuerchick.89.jpg
#   inflating: test_after_train7_5/zapnuerchick.9.jpg
#   inflating: test_after_train7_5/zapnuerchick.90.jpg
#   inflating: test_after_train7_5/zapnuerchick.91.jpg
#   inflating: test_after_train7_5/zapnuerchick.92.jpg
#   inflating: test_after_train7_5/zapnuerchick.93.jpg
#   inflating: test_after_train7_5/zapnuerchick.94.jpg
#   inflating: test_after_train7_5/zapnuerchick.95.jpg
#   inflating: test_after_train7_5/zapnuerchick.96.jpg
#   inflating: test_after_train7_5/zapnuerchick.97.jpg
#   inflating: test_after_train7_5/zapnuerchick.98.jpg
#   inflating: test_after_train7_5/zapnuerchick.99.jpg

# %%
testAfterTrainpath7_5 = 'test_after_train7_5/'
imageTestAfterTrainPaths7_5  = [testAfterTrainpath7_5 +f for f in listdir(testAfterTrainpath7_5 ) if isfile(join(testAfterTrainpath7_5 , f))]

# %%
test_after_train_list7_5 = []
test_after_train_list_ans7_5 = []
for (i, img_path_test_after_train7_5) in enumerate(imageTestAfterTrainPaths7_5):
      img = cv2.imread(img_path_test_after_train7_5)
      crop_img = to_crop_img(img)
      # orange_val = detect_orange(img)
      # yellow_val = detect_yellow(img)
      # green_val = detect_green(img)
      # color_list = np.array([orange_val,yellow_val,green_val])
      #test_list.append(np.array([(x-min(color_list))/(max(color_list)-min(color_list))  for x in color_list])+0.01) 
      avg_img = color_in_scale(crop_img)
      min_avg = min(avg_img)
      max_avg = max(avg_img)
      for i in range(len(avg_img)):
          avg_img[i] = (avg_img[i]-min_avg)/(max_avg-min_avg) 
      test_after_train_list7_5.append(avg_img)
      product_name = img_path_test_after_train7_5.split(".")[0].split("/")[1]
      product_class = 0
      if (product_name == "maeyupa"):
          product_class = 1
      elif (product_name == "ocean"):
          product_class = 2
      elif (product_name == "zapnuer"):
          product_class = 3
      elif (product_name == "zapnuerchick"):
          product_class = 4

      test_after_train_list_ans7_5.append(product_class-1)

# %%
fail_num = 1
scorecard = []
for  i in range(len(test_after_train_list7_5)):
    inputs =  test_after_train_list7_5[i]
    ans = test_after_train_list_ans7_5[i]
  
            
    outputs = n.query(inputs)
    
    # the index of the highest value corresponds to the label
    label = np.argmax(outputs)
    
    # append correct or incorrect to list
    if (label == ans):
        
        scorecard.append(1)
    else:
        # network's answer doesn't match correct answer, add 0 to scorecard
        scorecard.append(0)
        
        print(fail_num,' ',ans,' ',np.transpose(outputs))
        fail_num+=1
        pass
    pass
# calculate the performance score, the fraction of correct answers
scorecard_array = np.asarray(scorecard)
print ("performance = ", scorecard_array.sum() /scorecard_array.size*100)
# Out:
# 1   2   [[0.00110916 0.92003641 0.6822482  0.02264362]]
# 2   2   [[0.00098469 0.88297897 0.77366573 0.02663896]]
# performance =  99.81900452488688
