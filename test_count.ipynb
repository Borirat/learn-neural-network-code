# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

import numpy as np
import cv2
import os
import imutils

from sklearn.metrics import classification_report 
from sklearn.metrics import f1_score ,accuracy_score

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D

from os import listdir
from os.path import isfile, join
import tensorflow

# %%
batch_size = 32
num_classes = 4
#epochs = 16
data_augmentation = True
num_predictions = 20
width = 150
height = 150
#images = np.empty((0, 150,150,3))
labels = []
rawImage = []

# %%
model9 = Sequential()

model9.add(Conv2D(32, (3, 3), padding='same', input_shape=(150, 150, 3)))
model9.add(Activation('relu'))
model9.add(Conv2D(32, (3, 3), padding='same', input_shape=(150, 150, 3)))
model9.add(Activation('relu'))
model9.add(MaxPooling2D(pool_size=(2, 2)))

model9.add(Conv2D(64, (3, 3), padding='same'))
model9.add(Activation('relu'))
model9.add(MaxPooling2D(pool_size=(2, 2)))

model9.add(Conv2D(128, (3, 3), padding='same'))
model9.add(Activation('relu'))
model9.add(MaxPooling2D(pool_size=(2, 2)))

model9.add(Flatten())
model9.add(Dense(128))
model9.add(Activation('relu'))
model9.add(Dropout(0.5))
model9.add(Dense(4))
model9.add(Activation('sigmoid'))
model9.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])
model9.load_weights("/content/drive/My Drive/korat_sauce/train_sauce9.h5")

# %%
 from google.colab import drive
drive.mount('/content/drive')

# !unzip drive/"My Drive"/korat_sauce/count_pic3.zip
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archive:  drive/My Drive/korat_sauce/count_pic3.zip
#    creating: pic_from_count/
#   inflating: pic_from_count/all.0.ocean.jpg
#   inflating: pic_from_count/all.1.ocean.jpg
#   inflating: pic_from_count/all.10.zapnuerchick.jpg
#   inflating: pic_from_count/all.11.ocean.jpg
#   inflating: pic_from_count/all.12.maeyupa.jpg
#   inflating: pic_from_count/all.13.zapnuerchick.jpg
#   inflating: pic_from_count/all.14.zapnuerchick.jpg
#   inflating: pic_from_count/all.15.ocean.jpg
#   inflating: pic_from_count/all.16.zapnuerchick.jpg
#   inflating: pic_from_count/all.17.ocean.jpg
#   inflating: pic_from_count/all.18.maeyupa.jpg
#   inflating: pic_from_count/all.19.ocean.jpg
#   inflating: pic_from_count/all.2.zapnuer.jpg
#   inflating: pic_from_count/all.20.zapnuerchick.jpg
#   inflating: pic_from_count/all.21.zapnuer.jpg
#   inflating: pic_from_count/all.22.ocean.jpg
#   inflating: pic_from_count/all.23.zapnuer.jpg
#   inflating: pic_from_count/all.24.maeyupa.jpg
#   inflating: pic_from_count/all.25.zapnuerchick.jpg
#   inflating: pic_from_count/all.26.maeyupa.jpg
#   inflating: pic_from_count/all.27.ocean.jpg
#   inflating: pic_from_count/all.28.ocean.jpg
#   inflating: pic_from_count/all.29.zapnuerchick.jpg
#   inflating: pic_from_count/all.3.zapnuer.jpg
#   inflating: pic_from_count/all.30.zapnuerchick.jpg
#   inflating: pic_from_count/all.31.zapnuer.jpg
#   inflating: pic_from_count/all.32.zapnuer.jpg
#   inflating: pic_from_count/all.33.ocean.jpg
#   inflating: pic_from_count/all.34.maeyupa.jpg
#   inflating: pic_from_count/all.35.zapnuerchick.jpg
#   inflating: pic_from_count/all.36.ocean.jpg
#   inflating: pic_from_count/all.37.ocean.jpg
#   inflating: pic_from_count/all.38.maeyupa.jpg
#   inflating: pic_from_count/all.39.zapnuer.jpg
#   inflating: pic_from_count/all.4.zapnuerchick.jpg
#   inflating: pic_from_count/all.40.zapnuer.jpg
#   inflating: pic_from_count/all.41.ocean.jpg
#   inflating: pic_from_count/all.42.zapnuerchick.jpg
#   inflating: pic_from_count/all.43.maeyupa.jpg
#   inflating: pic_from_count/all.44.zapnuerchick.jpg
#   inflating: pic_from_count/all.45.zapnuer.jpg
#   inflating: pic_from_count/all.46.maeyupa.jpg
#   inflating: pic_from_count/all.47.zapnuer.jpg
#   inflating: pic_from_count/all.48.zapnuerchick.jpg
#   inflating: pic_from_count/all.49.ocean.jpg
#   inflating: pic_from_count/all.5.maeyupa.jpg
#   inflating: pic_from_count/all.50.ocean.jpg
#   inflating: pic_from_count/all.51.zapnuerchick.jpg
#   inflating: pic_from_count/all.52.maeyupa.jpg
#   inflating: pic_from_count/all.53.zapnuer.jpg
#   inflating: pic_from_count/all.54.zapnuerchick.jpg
#   inflating: pic_from_count/all.55.zapnuer.jpg
#   inflating: pic_from_count/all.56.ocean.jpg
#   inflating: pic_from_count/all.57.ocean.jpg
#   inflating: pic_from_count/all.58.zapnuer.jpg
#   inflating: pic_from_count/all.59.maeyupa.jpg
#   inflating: pic_from_count/all.6.zapnuer.jpg
#   inflating: pic_from_count/all.60.ocean.jpg
#   inflating: pic_from_count/all.61.ocean.jpg
#   inflating: pic_from_count/all.62.zapnuer.jpg
#   inflating: pic_from_count/all.63.zapnuerchick.jpg
#   inflating: pic_from_count/all.64.ocean.jpg
#   inflating: pic_from_count/all.65.zapnuerchick.jpg
#   inflating: pic_from_count/all.66.zapnuerchick.jpg
#   inflating: pic_from_count/all.67.maeyupa.jpg
#   inflating: pic_from_count/all.68.zapnuerchick.jpg
#   inflating: pic_from_count/all.69.ocean.jpg
#   inflating: pic_from_count/all.7.maeyupa.jpg
#   inflating: pic_from_count/all.70.maeyupa.jpg
#   inflating: pic_from_count/all.71.ocean.jpg
#   inflating: pic_from_count/all.72.maeyupa.jpg
#   inflating: pic_from_count/all.73.zapnuerchick.jpg
#   inflating: pic_from_count/all.74.ocean.jpg
#   inflating: pic_from_count/all.75.zapnuer.jpg
#   inflating: pic_from_count/all.76.zapnuerchick.jpg
#   inflating: pic_from_count/all.77.zapnuerchick.jpg
#   inflating: pic_from_count/all.78.maeyupa.jpg
#   inflating: pic_from_count/all.79.ocean.jpg
#   inflating: pic_from_count/all.8.zapnuerchick.jpg
#   inflating: pic_from_count/all.80.zapnuerchick.jpg
#   inflating: pic_from_count/all.81.maeyupa.jpg
#   inflating: pic_from_count/all.82.zapnuer.jpg
#   inflating: pic_from_count/all.83.zapnuerchick.jpg
#   inflating: pic_from_count/all.84.ocean.jpg
#   inflating: pic_from_count/all.85.zapnuerchick.jpg
#   inflating: pic_from_count/all.86.zapnuerchick.jpg
#   inflating: pic_from_count/all.87.maeyupa.jpg
#   inflating: pic_from_count/all.88.ocean.jpg
#   inflating: pic_from_count/all.89.ocean.jpg
#   inflating: pic_from_count/all.9.maeyupa.jpg
#   inflating: pic_from_count/all.90.zapnuer.jpg
#   inflating: pic_from_count/all.91.ocean.jpg
#   inflating: pic_from_count/all.92.ocean.jpg
#   inflating: pic_from_count/all.93.zapnuerchick.jpg
#   inflating: pic_from_count/all.94.zapnuer.jpg
#   inflating: pic_from_count/all.95.maeyupa.jpg
#   inflating: pic_from_count/all.96.zapnuer.jpg
#   inflating: pic_from_count/all.97.zapnuerchick.jpg
#   inflating: pic_from_count/all.98.ocean.jpg

# %%
mypath_test = 'pic_from_count/'
imagePaths_test = [mypath_test+f for f in listdir(mypath_test) if isfile(join(mypath_test, f))]

# %%
imagePaths_test.sort()

# %%
#######
for (i, img_path) in enumerate(imagePaths_test):
  #img_path = 'all_sauce/ocean.'+str(i)+'.jpg'
  img_list = []
  image = cv2.imread(img_path)
  image = cv2.resize(image, (width,height))
  img_list.append(image)
  img_list = np.array(img_list)
  img_list = img_list.astype('float32')


  # Remember that the model was trained on inputs
  # that were preprocessed in the following way:
  img_list /= 255.
  # Its shape is (1, 150, 150, 3)

  print(img_list.shape)
  print(img_path)

  #plt.imshow(img_list[0])
  #plt.imshow(X_test[0])
  #plt.show()

  prediction = model9.predict(np.array([img_list[0]]))
  #prediction = model.predict(np.array([X_test[0]]))
  print(prediction[0])
  print(max(prediction[0]))
  y_classes = prediction.argmax(axis=-1)
  print(y_classes)
  print("#####")
# Out:
# (1, 150, 150, 3)
# pic_from_count/all.0.ocean.jpg
# [5.2652034e-05 9.9991333e-01 3.7291918e-06 4.4772069e-06]
# 0.99991333
# [1]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.1.ocean.jpg
# [1.0951408e-12 1.0000000e+00 2.8534061e-19 5.5106615e-14]
# 1.0
# [1]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.10.zapnuerchick.jpg
# [2.9796362e-03 1.9312706e-06 1.8748164e-02 9.8091257e-01]
# 0.98091257
# [3]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.11.ocean.jpg
# [1.4477918e-18 1.0000000e+00 2.7238134e-31 3.3110740e-24]
# 1.0
# [1]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.12.maeyupa.jpg
# [9.9999726e-01 1.0058481e-07 4.9574416e-14 1.5223844e-09]
# 0.99999726
# [0]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.13.zapnuerchick.jpg
# [1.3371706e-03 6.5444483e-06 2.0681322e-03 9.9349809e-01]
# 0.9934981
# [3]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.14.zapnuerchick.jpg
# [8.161932e-03 7.892979e-05 9.443092e-05 9.886303e-01]
# 0.9886303
# [3]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.15.ocean.jpg
# [0.6682952  0.08924267 0.00186759 0.14687827]
# 0.6682952
# [0]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.16.zapnuerchick.jpg
# [0.44977134 0.00147623 0.00225815 0.71487284]
# 0.71487284
# [3]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.17.ocean.jpg
# [9.3305618e-02 9.3530917e-01 1.3300590e-07 1.6152859e-04]
# 0.9353092
# [1]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.18.maeyupa.jpg
# [9.8537451e-01 5.6723952e-03 6.6938996e-04 1.4611324e-05]
# 0.9853745
# [0]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.19.ocean.jpg
# [2.7644857e-05 9.9994993e-01 1.0997423e-07 1.6628798e-07]
# 0.99994993
# [1]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.2.zapnuer.jpg
# [1.6362899e-08 5.7335677e-15 5.1810813e-01 6.1545610e-02]
# 0.5181081
# [2]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.20.zapnuerchick.jpg
# [1.3009706e-01 4.8439269e-05 7.5843930e-04 9.2344880e-01]
# 0.9234488
# [3]
# #####
# (1, 150, 150, 3)
# pic_from_count/all

# #####
# (1, 150, 150, 3)
# pic_from_count/all.91.ocean.jpg
# [0.8525244  0.04378331 0.06901857 0.01001257]
# 0.8525244
# [0]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.92.ocean.jpg
# [0.6175631  0.38787895 0.00605303 0.00664425]
# 0.6175631
# [0]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.93.zapnuerchick.jpg
# [1.0055900e-03 4.1185140e-05 2.1692812e-03 9.9334931e-01]
# 0.9933493
# [3]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.94.zapnuer.jpg
# [3.8960630e-07 1.9130542e-07 9.9981070e-01 8.1465537e-08]
# 0.9998107
# [2]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.95.maeyupa.jpg
# [9.9956083e-01 1.2668967e-04 3.8444821e-09 6.9031944e-07]
# 0.99956083
# [0]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.96.zapnuer.jpg
# [1.6800666e-07 6.7723924e-09 3.2175612e-01 8.6967987e-01]
# 0.86967987
# [3]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.97.zapnuerchick.jpg
# [0.01145017 0.00197756 0.00510839 0.97364867]
# 0.97364867
# [3]
# #####
# (1, 150, 150, 3)
# pic_from_count/all.98.ocean.jpg
# [0.09648168 0.1388385  0.0024021  0.04624158]
# 0.1388385
# [1]
# #####

# %%
error_path = []
pic_true = 0
pic_false = 0
#######
for (i, img_path) in enumerate(imagePaths_test):
  #img_path = 'all_sauce/ocean.'+str(i)+'.jpg'
  label = img_path.split('/')[1].split('.')[2]
  img_list = []
  image = cv2.imread(img_path)
  image = cv2.resize(image, (width,height))
  img_list.append(image)
  img_list = np.array(img_list)
  img_list = img_list.astype('float32')


  # Remember that the model was trained on inputs
  # that were preprocessed in the following way:
  img_list /= 255.
  # Its shape is (1, 150, 150, 3)

  #print(img_list.shape)
  #print(img_path)

  #plt.imshow(img_list[0])
  #plt.imshow(X_test[0])
  #plt.show()

  prediction = model9.predict(np.array([img_list[0]]))
  #prediction = model.predict(np.array([X_test[0]]))
  #print(prediction[0])
  #print(max(prediction[0]))
  y_classes = prediction.argmax(axis=-1)
  if(label == "maeyupa"):
    if(y_classes[0]==0):
      pic_true+=1
    else:
      pic_false+=1
      error_path.append(img_path)
  elif(label == "ocean"):
    if(y_classes[0]==1):
      pic_true+=1
    else:
      pic_false+=1
      error_path.append(img_path)
  elif(label == "zapnuer"):
    if(y_classes[0]==2):
      pic_true+=1
    else:
      pic_false+=1
      error_path.append(img_path)
  elif(label == "zapnuerchick"):
    if(y_classes[0]==3):
      pic_true+=1
    else:
      pic_false+=1
      error_path.append(img_path)

  #print(y_classes)
  #print("#####")
print("summary ture = ",pic_true," ,false = ",pic_false)
for i  in error_path:
  print(i)
# Out:
# summary ture =  84  ,false =  15
# pic_from_count/all.15.ocean.jpg
# pic_from_count/all.24.maeyupa.jpg
# pic_from_count/all.39.zapnuer.jpg
# pic_from_count/all.43.maeyupa.jpg
# pic_from_count/all.5.maeyupa.jpg
# pic_from_count/all.52.maeyupa.jpg
# pic_from_count/all.60.ocean.jpg
# pic_from_count/all.61.ocean.jpg
# pic_from_count/all.65.zapnuerchick.jpg
# pic_from_count/all.74.ocean.jpg
# pic_from_count/all.88.ocean.jpg
# pic_from_count/all.89.ocean.jpg
# pic_from_count/all.91.ocean.jpg
# pic_from_count/all.92.ocean.jpg
# pic_from_count/all.96.zapnuer.jpg
