# %%
from google.colab import drive
drive.mount('/content/drive')

# !unzip drive/"My Drive"/dogs_cats/test1.zip

# %%
import cv2
import imageio
import matplotlib


img = imageio.imread("train/cat.302.jpg", as_gray=True)
#img = cv2.imread("cats_dogs/train/dog.1.jpg", 0) 
#cv2.imshow('image', img)
dim = (280, 280)
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
#print(img.astype(float))

img_data  = 255.0 - resized.reshape(78400)
img_data = (img_data / 255.0 * 0.99) + 0.01

#print(img_data)

matplotlib.pyplot.imshow(resized, cmap='Greys', interpolation='None')
