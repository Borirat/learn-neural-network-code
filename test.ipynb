# %%
import numpy as np

# %%
a = np.array([1,2,3],[4,5,6])
print(a+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a0c39cea4a60> in <module>()
# ----> 1 a = np.array([1,2,3],[4,5,6])
#       2 print(a+1)
#
# TypeError: Field elements must be 2- or 3-tuples, got '4'
